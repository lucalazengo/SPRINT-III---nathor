# %%
import pandas as pd
import os

# %%
df1 = pd.read_csv(
    r'../data/2025-06-13 - Dicionário cores.csv',
    sep=';',
    encoding='utf-8'  
)
df1.columns
# Out:
# Index(['COR_APELIDO', 'DESCRICAO_COMPONENTE', 'CODIGO_COMPONENTE'], dtype='object')

# %%
df1.info()
df1
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54 entries, 0 to 53
# Data columns (total 3 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   COR_APELIDO           54 non-null     object
#  1   DESCRICAO_COMPONENTE  54 non-null     object
#  2   CODIGO_COMPONENTE     54 non-null     int64
# dtypes: int64(1), object(2)
# memory usage: 1.4+ KB
#                     COR_APELIDO                       DESCRICAO_COMPONENTE  \
# 0               AMARELO DOURADO                TINTA EM PO AMARELO DOURADO
# 1          amarelo dourado free     TINTA HIBRID TGIC FREE AMARELO DOURADO
# 2                 azul clarinho              TINTA EM PO AZUL CLARINHO 283
# 3             AZUL CLARINHOFREE           TINTA HIBRID TGIC FREE AZUL BEBE
# 4                   azul escuro                    TINTA EM PO AZUL ESCURO
# 5                   AZUL ESCURO                    TINTA EM PO AZUL ESCURO
# 6                     azul flex           TINTA HIBRID TGIC FREE AZUL FLEX
# 7                     AZUL FLEX           TINTA HIBRID TGIC FREE AZUL FLEX
# 8           AZUL FLEX FREE TGIC           TINTA HIBRID TGIC FREE AZUL FLEX
# 9                AZUL FLEX  MAS            TINTA EM PO AZUL BRILHANTE FLEX
# 10                       branco                         TINTA EM PO BRANCA
# 11                       BRANCO                         TINTA EM PO BRANCA
# 12               BRANCO c /furo                         TINTA EM PO BRANCA
# 13             BRANCO FREE TGIC              TINTA HIBRID TGIC FREE BRANCA
# 14            C FURO ROSA CLARO                     TINTA EM PO ROSA CLARO
# 15                        cinza                          TINTA EM PO CINZA
# 16                   CORAL PINK                     TINTA EM PO CORAL PINK
# 17              free tgic preto       TINTA HIBRID TGIC FREE PRETO GRAFITE
# 18         FREE TGIC VERDE AQUA    TINTA HIBRID TGIC FREE VERDE AQUA PEROL
# 19                      grafite         TINTA EM PO GRAFITE METALICO FOSCO
# 20          grafite /RETRABALHO         TINTA EM PO GRAFITE METALICO FOSCO
# 21                      laranja                  TINTA EM PO LARANJA FOSCO
# 22                        lilas           TINTA EM PO LILAS - BANDEIRANTES
# 23                        LILAS           TINTA EM PO LILAS - BANDEIRANTES
# 24                        prata                          TINTA EM PO CINZA
# 25              PRATA FREE TGIC               TINTA HIBRID TGIC FREE PRATA
# 26                        preto                          TINTA EM PO PRETA
# 27                        PRETO                          TINTA EM PO PRETA
# 28                       PRETO,                          TINTA EM PO PRETA
# 29                  preto fosco                    TINTA EM PO PRETO FOSCO
# 30                  PRETO FOSCO                    TINTA EM PO PRETO FOSCO
# 31              preto free tgic       TINTA HIBRID TGIC FREE PRETO GRAFITE
# 32              PRETO FREE TGIC       TINTA HIBRID TGIC FREE PRETO GRAFITE
# 33            RAIADA PRETO FOSC                    TINTA EM PO PRETO FOSCO
# 34                      rosa 26       TINTA POLIESTER ROSA METALICO ARO 26
# 35                      ROSA 26       TINTA POLIESTER ROSA METALICO ARO 26
# 36           rosa 26 c/ch c/abr       TINTA POLIESTER ROSA METALICO ARO 26
# 37            rosa 26 free tgic     TINTA HIBRID TGIC FREE ROSA PEROLIZADO
# 38                ROSA CHICLETE                  TINTA EM PO ROSA CHICLETE
# 39                   rosa claro                     TINTA EM PO ROSA CLARO
# 40                  rosa claro,                     TINTA EM PO ROSA CLARO
# 41                   ROSA CLARO                     TINTA EM PO ROSA CLARO
# 42        rosa claro c/ abraÃ§a                     TINTA EM PO ROSA CLARO
# 43              ROSA CLARO FREE           TINTA HIBRID TGIC FREE ROSA BEBE
# 44         rosa claro free tgic           TINTA HIBRID TGIC FREE ROSA BEBE
# 45  rosa claro free  tgic  c/re           TINTA HIBRID TGIC FREE ROSA BEBE
# 46                  rosa escuro                    TINTA EM PO ROSA ESCURO
# 47                  ROSA ESCURO         TINTA HIBRID TGIC FREE ROSA ESCURO
# 48           rosa pe /free tgic     TINTA HIBRID TGIC FREE ROSA PEROLIZADO
# 49            verde aqua c furo  TINTA POLIEST VERDE AQUA METALICO ARO 2 6
# 50                     vermelho                       TINTA EM PO VERMELHO
# 51                     VERMELHO                       TINTA EM PO VERMELHO
# 52                        w eco                    TINTA EM PO PRETO W-ECO
# 53                        W ECO                    TINTA EM PO PRETO W-ECO
#
#     CODIGO_COMPONENTE
# 0        504010130069
# 1        504010130088
# 2        504010130042
# 3        504010130087
# 4        504010130006
# 5        504010130006
# 6        504010130098
# 7        504010130098
# 8        504010130098
# 9        504010130027
# 10       504010130001
# 11       504010130001
# 12       504010130001
# 13       504010130086
# 14       504010130015
# 15       504010130071
# 16       504010130072
# 17       504010130092
# 18       504010130089
# 19       504010130021
# 20       504010130021
# 21       504010130019
# 22       504010130025
# 23       504010130025
# 24       504010130071
# 25       504010130085
# 26       504010130007
# 27       504010130007
# 28       504010130007
# 29       504010130061
# 30       504010130061
# 31       504010130092
# 32       504010130092
# 33       504010130061
# 34       504010130037
# 35       504010130037
# 36       504010130037
# 37       504010130097
# 38       504010130067
# 39       504010130015
# 40       504010130015
# 41       504010130015
# 42       504010130015
# 43       504010130090
# 44       504010130090
# 45       504010130090
# 46       504010130002
# 47       504010130084
# 48       504010130097
# 49       504010130039
# 50       504010130010
# 51       504010130010
# 52       504010130074
# 53       504010130074

# %%
# Agrupa o DataFrame pelo 'CODIGO_COMPONENTE' e agrega os 'COR_APELIDO' em uma lista
mapeamento_cores = df1.groupby('CODIGO_COMPONENTE')['COR_APELIDO'].apply(list).reset_index()

# Renomeia a coluna para maior clareza
mapeamento_cores.rename(columns={'COR_APELIDO': 'VARIACOES_APELIDO'}, inplace=True)

# Exibe o novo DataFrame com o mapeamento
mapeamento_cores
# Out:
#     CODIGO_COMPONENTE                                  VARIACOES_APELIDO
# 0        504010130001                   [branco, BRANCO, BRANCO c /furo]
# 1        504010130002                                      [rosa escuro]
# 2        504010130006                         [azul escuro, AZUL ESCURO]
# 3        504010130007                             [preto, PRETO, PRETO,]
# 4        504010130010                               [vermelho, VERMELHO]
# 5        504010130015  [C FURO ROSA CLARO, rosa claro, rosa claro,, R...
# 6        504010130019                                          [laranja]
# 7        504010130021                     [grafite, grafite /RETRABALHO]
# 8        504010130025                                     [lilas, LILAS]
# 9        504010130027                                   [AZUL FLEX  MAS]
# 10       504010130037             [rosa 26, ROSA 26, rosa 26 c/ch c/abr]
# 11       504010130039                                [verde aqua c furo]
# 12       504010130042                                    [azul clarinho]
# 13       504010130061      [preto fosco, PRETO FOSCO, RAIADA PRETO FOSC]
# 14       504010130067                                    [ROSA CHICLETE]
# 15       504010130069                                  [AMARELO DOURADO]
# 16       504010130071                                     [cinza, prata]
# 17       504010130072                                       [CORAL PINK]
# 18       504010130074                                     [w eco, W ECO]
# 19       504010130084                                      [ROSA ESCURO]
# 20       504010130085                                  [PRATA FREE TGIC]
# 21       504010130086                                 [BRANCO FREE TGIC]
# 22       504010130087                                [AZUL CLARINHOFREE]
# 23       504010130088                             [amarelo dourado free]
# 24       504010130089                             [FREE TGIC VERDE AQUA]
# 25       504010130090  [ROSA CLARO FREE, rosa claro free tgic, rosa c...
# 26       504010130092  [free tgic preto, preto free tgic, PRETO FREE ...
# 27       504010130097            [rosa 26 free tgic, rosa pe /free tgic]
# 28       504010130098        [azul flex, AZUL FLEX, AZUL FLEX FREE TGIC]

# %%
# Quantidade de componentes por produto:
df1.groupby(['CODIGO_COMPONENTE'])['COR_APELIDO'].nunique().reset_index().sort_values('CODIGO_COMPONENTE', ascending=False)
# Out:
#     CODIGO_COMPONENTE  COR_APELIDO
# 28       504010130098            3
# 27       504010130097            2
# 26       504010130092            3
# 25       504010130090            3
# 24       504010130089            1
# 23       504010130088            1
# 22       504010130087            1
# 21       504010130086            1
# 20       504010130085            1
# 19       504010130084            1
# 18       504010130074            2
# 17       504010130072            1
# 16       504010130071            2
# 15       504010130069            1
# 14       504010130067            1
# 13       504010130061            3
# 12       504010130042            1
# 11       504010130039            1
# 10       504010130037            3
# 9        504010130027            1
# 8        504010130025            2
# 7        504010130021            2
# 6        504010130019            1
# 5        504010130015            5
# 4        504010130010            2
# 3        504010130007            3
# 2        504010130006            2
# 1        504010130002            1
# 0        504010130001            3

# %%
def limpar_e_unificar_apelidos(lista_apelidos):
    """
    Esta função recebe uma lista de strings e faz a limpeza:
    1. Converte tudo para minúsculas.
    2. Remove espaços em branco no início e no fim.
    3. Remove vírgulas e outros caracteres indesejados no final.
    4. Remove valores duplicados após a limpeza.
    """
    apelidos_unicos = set()
    for apelido in lista_apelidos:
        # Garante que o apelido é uma string, converte para minúsculo e remove espaços/vírgulas
        apelido_limpo = str(apelido).lower().strip().rstrip(',')
        
        # Adiciona ao conjunto de apelidos únicos
        if apelido_limpo: # Garante que strings vazias não sejam adicionadas
            apelidos_unicos.add(apelido_limpo)
            
    # Retorna como uma lista ordenada
    return sorted(list(apelidos_unicos))

# %%
# AgrupaR por CODIGO_COMPONENTE e agregar as informações relevantes
df_consolidado = df1.groupby('CODIGO_COMPONENTE').agg(
    # Cria uma lista com todos os apelidos do grupo
    VARIACOES_APELIDO=('COR_APELIDO', list),
    
    # Pega a primeira descrição encontrada (assumindo que é a mesma para o mesmo código)
    DESCRICAO=('DESCRICAO_COMPONENTE', 'first'),
    
    # Conta o número de linhas (ocorrências) em cada grupo
    QUANTIDADE=('CODIGO_COMPONENTE', 'size')
).reset_index()

# Limpeza na coluna de listas
df_consolidado['VARIACOES_APELIDO'] = df_consolidado['VARIACOES_APELIDO'].apply(limpar_e_unificar_apelidos)

# Reordena as colunas 
df_consolidado = df_consolidado[['CODIGO_COMPONENTE', 'DESCRICAO', 'QUANTIDADE', 'VARIACOES_APELIDO']]

df_consolidado
# Out:
#     CODIGO_COMPONENTE                                  DESCRICAO  QUANTIDADE  \
# 0        504010130001                         TINTA EM PO BRANCA           3
# 1        504010130002                    TINTA EM PO ROSA ESCURO           1
# 2        504010130006                    TINTA EM PO AZUL ESCURO           2
# 3        504010130007                          TINTA EM PO PRETA           3
# 4        504010130010                       TINTA EM PO VERMELHO           2
# 5        504010130015                     TINTA EM PO ROSA CLARO           5
# 6        504010130019                  TINTA EM PO LARANJA FOSCO           1
# 7        504010130021         TINTA EM PO GRAFITE METALICO FOSCO           2
# 8        504010130025           TINTA EM PO LILAS - BANDEIRANTES           2
# 9        504010130027            TINTA EM PO AZUL BRILHANTE FLEX           1
# 10       504010130037       TINTA POLIESTER ROSA METALICO ARO 26           3
# 11       504010130039  TINTA POLIEST VERDE AQUA METALICO ARO 2 6           1
# 12       504010130042              TINTA EM PO AZUL CLARINHO 283           1
# 13       504010130061                    TINTA EM PO PRETO FOSCO           3
# 14       504010130067                  TINTA EM PO ROSA CHICLETE           1
# 15       504010130069                TINTA EM PO AMARELO DOURADO           1
# 16       504010130071                          TINTA EM PO CINZA           2
# 17       504010130072                     TINTA EM PO CORAL PINK           1
# 18       504010130074                    TINTA EM PO PRETO W-ECO           2
# 19       504010130084         TINTA HIBRID TGIC FREE ROSA ESCURO           1
# 20       504010130085               TINTA HIBRID TGIC FREE PRATA           1
# 21       504010130086              TINTA HIBRID TGIC FREE BRANCA           1
# 22       504010130087           TINTA HIBRID TGIC FREE AZUL BEBE           1
# 23       504010130088     TINTA HIBRID TGIC FREE AMARELO DOURADO           1
# 24       504010130089    TINTA HIBRID TGIC FREE VERDE AQUA PEROL           1
# 25       504010130090           TINTA HIBRID TGIC FREE ROSA BEBE           3
# 26       504010130092       TINTA HIBRID TGIC FREE PRETO GRAFITE           3
# 27       504010130097     TINTA HIBRID TGIC FREE ROSA PEROLIZADO           2
# 28       504010130098           TINTA HIBRID TGIC FREE AZUL FLEX           3
#
#                                     VARIACOES_APELIDO
# 0                            [branco, branco c /furo]
# 1                                       [rosa escuro]
# 2                                       [azul escuro]
# 3                                             [preto]
# 4                                          [vermelho]
# 5   [c furo rosa claro, rosa claro, rosa claro c/ ...
# 6                                           [laranja]
# 7                      [grafite, grafite /retrabalho]
# 8                                             [lilas]
# 9                                    [azul flex  mas]
# 10                      [rosa 26, rosa 26 c/ch c/abr]
# 11                                [verde aqua c furo]
# 12                                    [azul clarinho]
# 13                   [preto fosco, raiada preto fosc]
# 14                                    [rosa chiclete]
# 15                                  [amarelo dourado]
# 16                                     [cinza, prata]
# 17                                       [coral pink]
# 18                                            [w eco]
# 19                                      [rosa escuro]
# 20                                  [prata free tgic]
# 21                                 [branco free tgic]
# 22                                [azul clarinhofree]
# 23                             [amarelo dourado free]
# 24                             [free tgic verde aqua]
# 25  [rosa claro free, rosa claro free  tgic  c/re,...
# 26                 [free tgic preto, preto free tgic]
# 27            [rosa 26 free tgic, rosa pe /free tgic]
# 28                   [azul flex, azul flex free tgic]

# %%
import re

# 1. lista de prefixos  a serem removidos.
#    É importante colocar os prefixos mais longos e específicos primeiro.
prefixos = [
    'TINTA POLIESTER',
    'TINTA POLIEST',
    'TINTA EM PO',
    'TINTA HIBRID'  
]

# 2. Crie uma expressão regular a partir da lista.
#    O caractere '|' funciona como um "OU".
#    O '^' garante que vamos procurar o padrão apenas no início da string.
regex_prefixos = r'^(' + '|'.join(prefixos) + ')'

# 3. Use .str.replace() com a expressão regular para criar a nova coluna.
#    - regex=True: informa ao pandas que o padrão é uma expressão regular.
#    - flags=re.IGNORECASE: ignora se o texto está em maiúsculas ou minúsculas.
#    - .str.strip(): remove espaços em branco do início e do fim.
#    - .str.lower(): padroniza tudo para minúsculas.

df_consolidado['cor_padrao'] = df_consolidado['DESCRICAO'].str.replace(
    regex_prefixos, '', regex=True, flags=re.IGNORECASE
).str.strip().str.lower()

# 4. Exiba o resultado para verificação
df_consolidado[['DESCRICAO', 'cor_padrao']].head(10)
# Out:
#                             DESCRICAO              cor_padrao
# 0                  TINTA EM PO BRANCA                  branca
# 1             TINTA EM PO ROSA ESCURO             rosa escuro
# 2             TINTA EM PO AZUL ESCURO             azul escuro
# 3                   TINTA EM PO PRETA                   preta
# 4                TINTA EM PO VERMELHO                vermelho
# 5              TINTA EM PO ROSA CLARO              rosa claro
# 6           TINTA EM PO LARANJA FOSCO           laranja fosco
# 7  TINTA EM PO GRAFITE METALICO FOSCO  grafite metalico fosco
# 8    TINTA EM PO LILAS - BANDEIRANTES    lilas - bandeirantes
# 9     TINTA EM PO AZUL BRILHANTE FLEX     azul brilhante flex

# %%
# Dicionário com os nomes antigos e novos das colunas
mapa_nomes = {
    'CODIGO_COMPONENTE': 'CODIGO_COR',
    'cor_padrao': 'DESC_COR'
}

# Renomeia as colunas usando o dicionário
df_consolidado = df_consolidado.rename(columns=mapa_nomes)

# Exibe os nomes das colunas atualizados para confirmar
print("Nomes das colunas atualizados:")
print(df_consolidado.columns)

print("\nDataFrame com as colunas renomeadas:")
print(df_consolidado.head())
# Out:
# Nomes das colunas atualizados:
# Index(['CODIGO_COR', 'DESCRICAO', 'QUANTIDADE', 'VARIACOES_APELIDO',
#        'DESC_COR'],
#       dtype='object')
#
# DataFrame com as colunas renomeadas:
#      CODIGO_COR                DESCRICAO  QUANTIDADE  \
# 0  504010130001       TINTA EM PO BRANCA           3
# 1  504010130002  TINTA EM PO ROSA ESCURO           1
# 2  504010130006  TINTA EM PO AZUL ESCURO           2
# 3  504010130007        TINTA EM PO PRETA           3
# 4  504010130010     TINTA EM PO VERMELHO           2
#
#           VARIACOES_APELIDO     DESC_COR
# 0  [branco, branco c /furo]       branca
# 1             [rosa escuro]  rosa escuro
# 2             [azul escuro]  azul escuro
# 3                   [preto]        preta
# 4                [vermelho]     vermelho

# %%
from builtins import print


df_consolidado.to_csv('dsc_cores.csv', index=False, encoding='utf-8-sig')

print("Arquivo 'dsc_cores.csv' salvo com sucesso!")

df_consolidado.to_excel('dsc_cores.xlsx', index=False)

print("Arquivo 'dsc_cores.xlsx' salvo com sucesso!")
# Out:
# Arquivo 'dsc_cores.csv' salvo com sucesso!
# Arquivo 'dsc_cores.xlsx' salvo com sucesso!

# %%
df_consolidado
# Out:
#     CODIGO_COMPONENTE                                  DESCRICAO  QUANTIDADE  \
# 0        504010130001                         TINTA EM PO BRANCA           3
# 1        504010130002                    TINTA EM PO ROSA ESCURO           1
# 2        504010130006                    TINTA EM PO AZUL ESCURO           2
# 3        504010130007                          TINTA EM PO PRETA           3
# 4        504010130010                       TINTA EM PO VERMELHO           2
# 5        504010130015                     TINTA EM PO ROSA CLARO           5
# 6        504010130019                  TINTA EM PO LARANJA FOSCO           1
# 7        504010130021         TINTA EM PO GRAFITE METALICO FOSCO           2
# 8        504010130025           TINTA EM PO LILAS - BANDEIRANTES           2
# 9        504010130027            TINTA EM PO AZUL BRILHANTE FLEX           1
# 10       504010130037       TINTA POLIESTER ROSA METALICO ARO 26           3
# 11       504010130039  TINTA POLIEST VERDE AQUA METALICO ARO 2 6           1
# 12       504010130042              TINTA EM PO AZUL CLARINHO 283           1
# 13       504010130061                    TINTA EM PO PRETO FOSCO           3
# 14       504010130067                  TINTA EM PO ROSA CHICLETE           1
# 15       504010130069                TINTA EM PO AMARELO DOURADO           1
# 16       504010130071                          TINTA EM PO CINZA           2
# 17       504010130072                     TINTA EM PO CORAL PINK           1
# 18       504010130074                    TINTA EM PO PRETO W-ECO           2
# 19       504010130084         TINTA HIBRID TGIC FREE ROSA ESCURO           1
# 20       504010130085               TINTA HIBRID TGIC FREE PRATA           1
# 21       504010130086              TINTA HIBRID TGIC FREE BRANCA           1
# 22       504010130087           TINTA HIBRID TGIC FREE AZUL BEBE           1
# 23       504010130088     TINTA HIBRID TGIC FREE AMARELO DOURADO           1
# 24       504010130089    TINTA HIBRID TGIC FREE VERDE AQUA PEROL           1
# 25       504010130090           TINTA HIBRID TGIC FREE ROSA BEBE           3
# 26       504010130092       TINTA HIBRID TGIC FREE PRETO GRAFITE           3
# 27       504010130097     TINTA HIBRID TGIC FREE ROSA PEROLIZADO           2
# 28       504010130098           TINTA HIBRID TGIC FREE AZUL FLEX           3
#
#                                     VARIACOES_APELIDO  \
# 0                            [branco, branco c /furo]
# 1                                       [rosa escuro]
# 2                                       [azul escuro]
# 3                                             [preto]
# 4                                          [vermelho]
# 5   [c furo rosa claro, rosa claro, rosa claro c/ ...
# 6                                           [laranja]
# 7                      [grafite, grafite /retrabalho]
# 8                                             [lilas]
# 9                                    [azul flex  mas]
# 10                      [rosa 26, rosa 26 c/ch c/abr]
# 11                                [verde aqua c furo]
# 12                                    [azul clarinho]
# 13                   [preto fosco, raiada preto fosc]
# 14                                    [rosa chiclete]
# 15                                  [amarelo dourado]
# 16                                     [cinza, prata]
# 17                                       [coral pink]
# 18                                            [w eco]
# 19                                      [rosa escuro]
# 20                                  [prata free tgic]
# 21                                 [branco free tgic]
# 22                                [azul clarinhofree]
# 23                             [amarelo dourado free]
# 24                             [free tgic verde aqua]
# 25  [rosa claro free, rosa claro free  tgic  c/re,...
# 26                 [free tgic preto, preto free tgic]
# 27            [rosa 26 free tgic, rosa pe /free tgic]
# 28                   [azul flex, azul flex free tgic]
#
#                      cor_padrao
# 0                        branca
# 1                   rosa escuro
# 2                   azul escuro
# 3                         preta
# 4                      vermelho
# 5                    rosa claro
# 6                 laranja fosco
# 7        grafite metalico fosco
# 8          lilas - bandeirantes
# 9           azul brilhante flex
# 10         rosa metalico aro 26
# 11  verde aqua metalico aro 2 6
# 12            azul clarinho 283
# 13                  preto fosco
# 14                rosa chiclete
# 15              amarelo dourado
# 16                        cinza
# 17                   coral pink
# 18                  preto w-eco
# 19        tgic free rosa escuro
# 20              tgic free prata
# 21             tgic free branca
# 22          tgic free azul bebe
# 23    tgic free amarelo dourado
# 24   tgic free verde aqua perol
# 25          tgic free rosa bebe
# 26      tgic free preto grafite
# 27    tgic free rosa perolizado
# 28          tgic free azul flex

# %% [markdown]
# Aqui termina o data_engeneer do dataset das cores

# %%
df2 = pd.read_csv(
    r'../data/2025-06-13 - Estruturas - Produto x Tinta Pó - atualizado.csv',
    encoding='ISO-8859-1',
    sep=';'
)
df2
# Out:
#       CODIGO_PRODUTO Complemento                         DESCRICAO_PRODUTO  \
# 0       1.000102e+11                          BICICLETA ARO 12 BLACK 12 4
# 1       1.000102e+11                          BICICLETA ARO 12 BLACK 12 4
# 2       1.000102e+11                          BICICLETA ARO 12 BLACK 12 4
# 3       1.000102e+11                          BICICLETA ARO 12 BLACK 12 4
# 4       1.000102e+11                          BICICLETA ARO 12 BLACK 12 4
# ...              ...         ...                                       ...
# 1137    2.071002e+11      0002    RODA DIANTEIRA ARO 20 - 28 FUROS PRET O
# 1138    2.071002e+11      0002    RODA DIANTEIRA ARO 20 - 28 FUROS PRET O
# 1139    2.071002e+11      0001     RODA TRASEIRA ARO 20 COM MARCHA PT/P T
# 1140    2.071002e+11      0001     RODA TRASEIRA ARO 20 COM MARCHA PT/P T
# 1141             NaN         NaN                                       NaN
#
#       CODIGO_COMPONENTE Complemento_Componente PINTURA_ITEM   LINHA  \
# 0          2.060102e+11                 0001       Garfo 12  Aro 12
# 1          2.060102e+11                 0001     GuidÃ£o 12  Aro 12
# 2          2.060102e+11                 0001      Quadro 12  Aro 12
# 3          3.045102e+11                 0002    Pedivela 12  Aro 12
# 4          5.040101e+11                                 NaN     NaN
# ...                 ...                    ...          ...     ...
# 1137       2.071002e+11                 0001    Roda Aro 20  Aro 20
# 1138       5.040101e+11                                 NaN     NaN
# 1139       2.071002e+11                 0001    Roda Aro 20  Aro 20
# 1140       5.040101e+11                                 NaN     NaN
# 1141                NaN                    NaN    Quadro 12     NaN
#
#                        DESCRICAO_COMPONENTE
# 0     PINTURA GARFO DIANTEIRO ARO 12 PRETO
# 1              PINTURA GUIDAO ARO 12 PRETO
# 2        PINTURA QUADRO ARO 12 MOD02 PRETO
# 3                  PINTURA PEDIVELA BRANCO
# 4                       TINTA EM PO BRANCA
# ...                                     ...
# 1137               PINTURA DO ARO 20 PRETO
# 1138                     TINTA EM PO PRETA
# 1139               PINTURA DO ARO 20 PRETO
# 1140                     TINTA EM PO PRETA
# 1141                                    NaN
#
# [1142 rows x 8 columns]

# %%
df2.columns
# Out:
# Index(['CODIGO_PRODUTO', 'Complemento', 'DESCRICAO_PRODUTO',
#        'CODIGO_COMPONENTE', 'Complemento_Componente', 'PINTURA_ITEM', 'LINHA',
#        'DESCRICAO_COMPONENTE'],
#       dtype='object')

# %%
# --- 1. Definição do Mapa de Cores ---
# Regras mais específicas (com mais palavras) vêm ANTES de regras mais gerais.
# Ex: 'GRAFITE METALICO FOSCO' é verificado antes de 'GRAFITE'.

MAPA_DE_CORES = [
    # Regras de 3 palavras
    ('GRAFITE METALICO FOSCO', 'grafite metalico fosco'),
    ('AZUL BRILHANTE FLEX', 'azul brilhante flex'),

    # Regras de 2 palavras
    ('ROSA ESCURO', 'rosa escuro'),
    ('AZUL ESCURO', 'azul escuro'),
    ('ROSA CLARO', 'rosa claro'),
    ('ROSA METALICO', 'rosa metalico aro 26'),
    ('PRETO FOSCO', 'preto fosco'),
    ('PRETO GRAFITE', 'tgic free preto grafite'),
    ('ROSA CHICLETE', 'rosa chiclete'),
    ('AMARELO DOURADO', 'amarelo dourado'),
    ('CORAL PINK', 'coral pink'),
    ('AZUL BEBE', 'tgic free azul bebe'),
    ('ROSA BEBE', 'tgic free rosa bebe'),
    ('ROSA PEROL', 'tgic free rosa perolizado'),
    ('AZUL FLEX', 'tgic free azul flex'),
    ('AZUL CLARO', 'azul claro'),
    ('AZUL CLARINHO', 'azul claro'),
    ('BRANCO', 'branca'),
    ('BRANCA', 'branca'),
    ('VERMELHO', 'vermelho'),
    ('GRAFITE', 'grafite metalico fosco'),
    ('CINZA', 'cinza'),
    ('LILAS', 'lilas - bandeirantes'), # Pega 'LILAS - BANDEIRANTE' e 'LILAS'
    ('VERDE', 'verde'),
    ('VERDE AQUA', 'verde'),
    ('COBRE', 'preto fosco'),
    ('PRETO', 'preta'),
    ('PRATA', 'tgic free prata'),
    ('AMARELO', 'amarelo dourado'),
]

def mapear_cor(descricao_componente):
    """
    Mapeia a cor de uma descrição de componente usando o MAPA_DE_CORES.
    Ignora componentes que não começam com 'PINTURA'.
    """
    # 1. Ignorar linhas que não são de pintura
    if not isinstance(descricao_componente, str) or not descricao_componente.upper().startswith('PINTURA'):
        return np.nan

    # 2. Limpar a descrição para uma correspondência robusta
    #    - Converte para maiúsculas
    #    - Remove espaços extras entre palavras
    #    - Remove todos os espaços para lidar com erros como "BRA NCA" -> "BRANCA"
    texto_limpo = descricao_componente.upper()
    texto_limpo_sem_espacos = texto_limpo.replace(' ', '')

    # 3. Iterar sobre o mapa e encontrar a primeira correspondência
    for termo_busca, cor_padrao in MAPA_DE_CORES:
        # A busca sem espaços lida com erros de digitação (ex: "ROSAMETALICO")
        termo_busca_sem_espacos = termo_busca.replace(' ', '')
        if termo_busca_sem_espacos in texto_limpo_sem_espacos:
            return cor_padrao # Retorna a cor padrão e para a busca

    # 4. Se nenhuma correspondência for encontrada, retorna NaN
    return np.nan

# --- Bloco Principal de Execução ---

# 1. Carregamento do Arquivo
caminho_arquivo = r'../data/2025-06-13 - Estruturas - Produto x Tinta Pó - atualizado.csv'
try:
    df = pd.read_csv(caminho_arquivo, encoding='ISO-8859-1', sep=';')
    print(f"Arquivo '{caminho_arquivo}' carregado com sucesso.")
except FileNotFoundError:
    print(f"ERRO: Arquivo não encontrado em '{caminho_arquivo}'. Verifique o caminho.")
    exit()

# 2. Aplicação da Lógica de Mapeamento
print("Iniciando mapeamento de cores...")
df['DESC_COR'] = df['DESCRICAO_COMPONENTE'].apply(mapear_cor)
print("Mapeamento concluído.")

# 3. Validação e Relatório
print("\n--- RELATÓRIO DE VALIDAÇÃO ---")

# Filtra apenas as linhas que deveriam ser processadas (iniciam com PINTURA)
df_pintura = df[df['DESCRICAO_COMPONENTE'].str.upper().str.startswith('PINTURA', na=False)]
total_pintura = len(df_pintura)

# Separa as que tiveram sucesso e as que falharam
sucesso = df_pintura.dropna(subset=['DESC_COR'])
falha = df_pintura[df_pintura['DESC_COR'].isnull()]

print(f"Total de linhas com 'PINTURA' encontradas: {total_pintura}")
print(f"  - Cores extraídas com sucesso: {len(sucesso)}")
print(f"  - Falhas na extração: {len(falha)}")

if not falha.empty:
    print("\n>>> ANÁLISE NECESSÁRIA: Não foi possível extrair a cor das seguintes linhas:")
    # Apresenta o conteúdo completo das linhas com falha para análise
    with pd.option_context('display.max_rows', None, 'display.max_columns', None, 'display.width', 1000):
        print(falha)
else:
    print("\n>>> SUCESSO: Todas as linhas com 'PINTURA' foram mapeadas com sucesso!")

# Mostra uma prévia das cores extraídas com sucesso
if not sucesso.empty:
    print("\n--- AMOSTRA DAS CORES EXTRAÍDAS COM SUCESSO ---")
    print(sucesso[['DESCRICAO_COMPONENTE', 'DESC_COR']].head(10).to_string())

# 4. Salvando o Resultado
caminho_saida = 'produtos_com_cores_mapeadas.csv'
df.to_csv(caminho_saida, index=False, sep=';', encoding='ISO-8859-1')
print(f"\nArquivo final com a coluna 'DESC_COR' foi salvo em: '{caminho_saida}'")
# Out:
# Arquivo '../data/2025-06-13 - Estruturas - Produto x Tinta Pó - atualizado.csv' carregado com sucesso.
# Iniciando mapeamento de cores...
# Mapeamento concluído.
#
# --- RELATÓRIO DE VALIDAÇÃO ---
# Total de linhas com 'PINTURA' encontradas: 710
#   - Cores extraídas com sucesso: 601
#   - Falhas na extração: 109
#
# >>> ANÁLISE NECESSÁRIA: Não foi possível extrair a cor das seguintes linhas:
#       CODIGO_PRODUTO Complemento                                DESCRICAO_PRODUTO  CODIGO_COMPONENTE Complemento_Componente     PINTURA_ITEM    LINHA                               DESCRICAO_COMPONENTE DESC_COR
# 12      1.000102e+11                            BICICLETA ARO 12 CAT 01 SELIM PU        2.060102e+11                 0007           Garfo 12   Aro 12         PINTURA GARFO DIANTEIRO ARO 12 ROSA CLA R       NaN
# 37      1.000102e+11                                      BICICLETA ARO 12 CHARM        2.060102e+11                 0007           Garfo 12   Aro 12         PINTURA GARFO DIANTEIRO ARO 12 ROSA CLA R       NaN
# 84      1.001302e+11                                BICICLETA ARO 16 TECH BOYS 5        2.070102e+11                 0001    AbraÃ§adeira 16   Aro 16              PINTURA ABRACADEIRA SELIM 16/BALANCE       NaN
# 90      1.001302e+11                                    BICICLETA ARO 16 PIXIE 2        2.070102e+11                 0001    AbraÃ§adeira 16   Aro 16              PINTURA ABRACADEIRA SELIM 16/BALANCE       NaN
# 99      1.001302e+11                                     BICICLETA ARO 16 LADY 3        2.070102e+11                 0001    AbraÃ§adeira 16   Aro 16              PINTURA ABRACADEIRA SELIM 16/BALANCE       NaN
# 108     1.001302e+11                                BICICLETA ARO 16 TOP GIRLS 6        2.070102e+11                 0001    AbraÃ§adeira 16   Aro 16              PINTURA ABRACADEIRA SELIM 16/BALANCE       NaN
# 113     1.001302e+11                                  BICICLETA ARO 16 EXTREME 2        2.070102e+11                 0018           Garfo 16   Aro 16            PINTURA GARFO DIANTEIRO ARO 16 LARANJA       NaN
# 114     1.001302e+11                                  BICICLETA ARO 16 EXTREME 2        2.070102e+11                 0018         GuidÃ£o 16   Aro 16                     PINTURA GUIDAO ARO 16 LARANJA       NaN
# 115     1.001302e+11                                  BICICLETA ARO 16 EXTREME 2        2.070102e+11                 0018          Quadro 16   Aro 16                     PINTURA QUADRO ARO 16 LARANJA       NaN
# 117     1.001302e+11                                  BICICLETA ARO 16 EXTREME 2        2.070102e+11                 0001    AbraÃ§adeira 16   Aro 16              PINTURA ABRACADEIRA SELIM 16/BALANCE       NaN
# 126     1.001302e+11                                BICICLETA ARO 16 TECH BOYS 6        2.070102e+11                 0001    AbraÃ§adeira 16   Aro 16              PINTURA ABRACADEIRA SELIM 16/BALANCE       NaN
# 134     1.001302e+11                                   BICICLETA ARO 16 APOLLO 4        2.070102e+11                 0001    AbraÃ§adeira 16   Aro 16              PINTURA ABRACADEIRA SELIM 16/BALANCE       NaN
# 143     1.001302e+11                                    BICICLETA ARO 16 UNICORN        2.070102e+11                 0001    AbraÃ§adeira 16   Aro 16              PINTURA ABRACADEIRA SELIM 16/BALANCE       NaN
# 196     1.001902e+11                            BICICLETA ARO 14 BTWIN ROBOT 14"        2.060302e+11                 0018          Quadro 14   Aro 14                 PINTURA QUADRO ARO 14 DEC LARANJA       NaN
# 224     1.002802e+11                                BICICLETA ARO 16 BTWIN ROBOT        2.070102e+11                 0018          Quadro 16   Aro 16               PINTURA QUADRO 16 DECATHLON LARANJA       NaN
# 286     1.002902e+11                           BICICLETA ARO 26 ANTONELLA PEROLA        2.071502e+11                 0056           Garfo 26   Aro 26             PINTURA GARFO DIANTEIRO ARO 26 PEROLA       NaN
# 287     1.002902e+11                           BICICLETA ARO 26 ANTONELLA PEROLA        2.071502e+11                 0056         GuidÃ£o 26   Aro 26                      PINTURA GUIDAO ARO 26 PEROLA       NaN
# 288     1.002902e+11                           BICICLETA ARO 26 ANTONELLA PEROLA        2.071502e+11                 0056          Quadro 26   Aro 26                      PINTURA QUADRO ARO 26 PEROLA       NaN
# 289     1.002902e+11                           BICICLETA ARO 26 ANTONELLA PEROLA        2.071502e+11                 0055        Cestinha 26   Aro 26                   PINTURA CESTINHA ARO 26 MARROM        NaN
# 290     1.002902e+11                           BICICLETA ARO 26 ANTONELLA PEROLA        2.071502e+11                 0055       Bagageiro 26   Aro 26        PINTURA BAGAGUEIRO TRASEIRO ARO 26 MAR ROM       NaN
# 295     1.002902e+11                             BICICLETA ARO 26 ANTONELLA ROSA        2.071502e+11                 0007           Garfo 26   Aro 26               PINTURA GARFO DIANTEIRO ARO 26 ROSA       NaN
# 296     1.002902e+11                             BICICLETA ARO 26 ANTONELLA ROSA        2.071502e+11                 0007         GuidÃ£o 26   Aro 26                        PINTURA GUIDAO ARO 26 ROSA       NaN
# 297     1.002902e+11                             BICICLETA ARO 26 ANTONELLA ROSA        2.071502e+11                 0007          Quadro 26   Aro 26                        PINTURA QUADRO ARO 26 ROSA       NaN
# 322     1.002902e+11                                BICICLETA ARO 26 ANTHON AZUL        2.071502e+11                 0067           Garfo 26   Aro 26      PINTURA GARFO DIANTEIRO ARO 26 AZUL RAL 5019       NaN
# 323     1.002902e+11                                BICICLETA ARO 26 ANTHON AZUL        2.071502e+11                 0067         GuidÃ£o 26   Aro 26                PINTURA GUIDAO ARO 26 AZUL RAL5019       NaN
# 324     1.002902e+11                                BICICLETA ARO 26 ANTHON AZUL        2.071502e+11                 0067          Quadro 26   Aro 26                PINTURA QUADRO ARO 26 AZUL RAL5019       NaN
# 362     1.003602e+11                           BICICLETA ARO 26 MOBHIS AZUL 5019        2.071502e+11                 0067         GuidÃ£o 26   Aro 26                PINTURA GUIDAO ARO 26 AZUL RAL5019       NaN
# 365     1.003602e+11                           BICICLETA ARO 26 MOBHIS AZUL 5019        2.071502e+11                 0067           Garfo 26   Aro 26  PINTURA GARFO DIANTEIRO ARO 26 MOBHIS 0 1 AZUL...      NaN
# 366     1.003602e+11                           BICICLETA ARO 26 MOBHIS AZUL 5019        2.071502e+11                 0067          Quadro 26   Aro 26        PINTURA QUADRO ARO 26 MOBHIS AZUL RAL5 019       NaN
# 370     1.004602e+11                                 BICICLETA ARO 26 LOUIS AZUL        2.071502e+11                 0047           Garfo 26   Aro 26      PINTURA GARFO DIANTEIRO ARO 26 AZUL MAR INHO       NaN
# 371     1.004602e+11                                 BICICLETA ARO 26 LOUIS AZUL        2.071502e+11                 0047         GuidÃ£o 26   Aro 26                PINTURA GUIDAO ARO 26 AZUL MARINHO       NaN
# 373     1.004602e+11                                 BICICLETA ARO 26 LOUIS AZUL        2.071502e+11                 0047          Quadro 26   Aro 26  PINTURA QUADRO ARO 26 S/CAMBIO PE LATER AZUL M...      NaN
# 431     1.006002e+11                               BICICLETA ARO 16 INFANTI ROSA        2.070102e+11                 0001    AbraÃ§adeira 16   Aro 16              PINTURA ABRACADEIRA SELIM 16/BALANCE       NaN
# 436     1.006002e+11                            BICICLETA ARO 16 INFANTI LARANJA        2.070102e+11                 0018           Garfo 16   Aro 16            PINTURA GARFO DIANTEIRO ARO 16 LARANJA       NaN
# 437     1.006002e+11                            BICICLETA ARO 16 INFANTI LARANJA        2.070102e+11                 0018         GuidÃ£o 16   Aro 16                     PINTURA GUIDAO ARO 16 LARANJA       NaN
# 438     1.006002e+11                            BICICLETA ARO 16 INFANTI LARANJA        2.070102e+11                 0018          Quadro 16   Aro 16                     PINTURA QUADRO ARO 16 LARANJA       NaN
# 440     1.006002e+11                            BICICLETA ARO 16 INFANTI LARANJA        2.070102e+11                 0001    AbraÃ§adeira 16   Aro 16              PINTURA ABRACADEIRA SELIM 16/BALANCE       NaN
# 453     1.006102e+11                              BICICLETA ARO 20 INFANTI PT/LJ        2.071002e+11                 0018           Garfo 20   Aro 20            PINTURA GARFO DIANTEIRO ARO 20 LARANJA       NaN
# 454     1.006102e+11                              BICICLETA ARO 20 INFANTI PT/LJ        2.071002e+11                 0018         GuidÃ£o 20   Aro 20                     PINTURA GUIDAO ARO 20 LARANJA       NaN
# 465     1.006202e+11                              BICICLETA ARO 12 INFANTI RS/VD        2.060102e+11                 0007           Garfo 12   Aro 12         PINTURA GARFO DIANTEIRO ARO 12 ROSA CLA R       NaN
# 471     1.007102e+11                              BICICLETA ARO 26 INBRASUL AZUL        2.071502e+11                 0067           Garfo 26   Aro 26      PINTURA GARFO DIANTEIRO ARO 26 AZUL RAL 5019       NaN
# 472     1.007102e+11                              BICICLETA ARO 26 INBRASUL AZUL        2.071502e+11                 0067         GuidÃ£o 26   Aro 26                PINTURA GUIDAO ARO 26 AZUL RAL5019       NaN
# 476     1.007102e+11                              BICICLETA ARO 26 INBRASUL AZUL        2.071502e+11                 0067          Quadro 26   Aro 26            PINTURA QUADRO ARO 26 INBRASUL RAL5019       NaN
# 482     1.007402e+11                           BICICLETA ARO 20 MOBHIS AZUL 5019        2.071002e+11                 0067           Garfo 20   Aro 20  PINTURA GARFO DIANTEIRO ARO 20 MOBHIS A ZUL 5019       NaN
# 483     1.007402e+11                           BICICLETA ARO 20 MOBHIS AZUL 5019        2.071002e+11                 0067         GuidÃ£o 20   Aro 20            PINTURA GUIDAO ARO 20 MOBHIS AZUL 5019       NaN
# 484     1.007402e+11                           BICICLETA ARO 20 MOBHIS AZUL 5019        2.071002e+11                 0067          Quadro 20   Aro 20     PINTURA QUADRO ARO 20 MOBHIS ABRAC AZU L 5019       NaN
# 516     1.007902e+11                        BICICLETA ARO 16 ABSOLUTE DINOSSAURO        2.070102e+11                 0001    AbraÃ§adeira 16   Aro 16              PINTURA ABRACADEIRA SELIM 16/BALANCE       NaN
# 522     1.007902e+11                         BICICLETA ARO 16 ABSOLUTE UNICORNIO        2.070102e+11                 0001    AbraÃ§adeira 16   Aro 16              PINTURA ABRACADEIRA SELIM 16/BALANCE       NaN
# 528     1.009002e+11                           BICICLETA BALANCE BIKE FAST MOD 3        2.070102e+11                 0001    AbraÃ§adeira 16  Balance              PINTURA ABRACADEIRA SELIM 16/BALANCE       NaN
# 536     1.009002e+11                     BICICLETA BALANCE BIKE MASCULINA MOD  5        2.070102e+11                 0001    AbraÃ§adeira 16  Balance              PINTURA ABRACADEIRA SELIM 16/BALANCE       NaN
# 541     1.009002e+11                       BICICLETA BALANCE BIKE ROCKET ASTRO 2        2.060102e+11                 0018      Garfo Balance  Balance            PINTURA GARFO DIANTEIRO ARO 12 LARANJA       NaN
# 543     1.009002e+11                       BICICLETA BALANCE BIKE ROCKET ASTRO 2        2.060102e+11                 0018     Quadro Balance  Balance             PINTURA QUADRO ARO 12 BALANCE LARANJA       NaN
# 544     1.009002e+11                       BICICLETA BALANCE BIKE ROCKET ASTRO 2        2.070102e+11                 0001    AbraÃ§adeira 16  Balance              PINTURA ABRACADEIRA SELIM 16/BALANCE       NaN
# 549     1.009002e+11                           BICICLETA BALANCE BIKE FEMININA 3        2.060102e+11                 0013      Garfo Balance  Balance         PINTURA GARFO DIANTEIRO ARO 12 ROSA ES CU       NaN
# 552     1.009002e+11                           BICICLETA BALANCE BIKE FEMININA 3        2.070102e+11                 0001    AbraÃ§adeira 16  Balance              PINTURA ABRACADEIRA SELIM 16/BALANCE       NaN
# 560     1.009002e+11                         BICICLETA BALANCE BIKE GARDEN FLY 2        2.070102e+11                 0001    AbraÃ§adeira 16  Balance              PINTURA ABRACADEIRA SELIM 16/BALANCE       NaN
# 565     1.009002e+11                               BICICLETA BALANCE BIKE LOVE 2        2.060102e+11                 0017      Garfo Balance  Balance     PINTURA GARFO DIANTEIRO ARO 12 ROSA (AR O 26)       NaN
# 566     1.009002e+11                               BICICLETA BALANCE BIKE LOVE 2        2.060102e+11                 0017    GuidÃ£o Balance  Balance  PINTURA GUIDAO ARO 12 BALANCE BIKE ROSA (ARO 26)       NaN
# 567     1.009002e+11                               BICICLETA BALANCE BIKE LOVE 2        2.060102e+11                 0017     Quadro Balance  Balance      PINTURA QUADRO ARO 12 BALANCE ROSA (AR O 26)       NaN
# 568     1.009002e+11                               BICICLETA BALANCE BIKE LOVE 2        2.070102e+11                 0001    AbraÃ§adeira 16  Balance              PINTURA ABRACADEIRA SELIM 16/BALANCE       NaN
# 574     1.009102e+11                      BICICLETA BTWIN BALANCE LARANJA/PRET O        2.060102e+11                 0018     Quadro Balance  Balance        PINTURA QUADRO ARO 12 BALANCE DEC LARA NJA       NaN
# 576     1.009102e+11                      BICICLETA BTWIN BALANCE LARANJA/PRET O        2.070102e+11                 0001    AbraÃ§adeira 16  Balance              PINTURA ABRACADEIRA SELIM 16/BALANCE       NaN
# 585     1.009102e+11                            BICICLETA BTWIN 100 PT/VERD 2022        2.070102e+11                 0001    AbraÃ§adeira 16  Balance              PINTURA ABRACADEIRA SELIM 16/BALANCE       NaN
# 593     1.009102e+11                     BICICLETA BTWIN 500 AZUL CLARO /PT 2022        2.070102e+11                 0001    AbraÃ§adeira 16  Balance              PINTURA ABRACADEIRA SELIM 16/BALANCE       NaN
# 602     1.009102e+11                       BICICLETA BTWIN 500 ROSA /MARROM 2022        2.070102e+11                 0001    AbraÃ§adeira 16  Balance              PINTURA ABRACADEIRA SELIM 16/BALANCE       NaN
# 631     1.009102e+11                                 BICICLETA RUN RIDE 100 ROSA        2.070102e+11                 0001    AbraÃ§adeira 16  Balance              PINTURA ABRACADEIRA SELIM 16/BALANCE       NaN
# 639     1.009302e+11                              BICICLETA BALANCE CECIZINHA 03        2.070102e+11                 0001    AbraÃ§adeira 16  Balance              PINTURA ABRACADEIRA SELIM 16/BALANCE       NaN
# 647     1.009302e+11                              BICICLETA BALANCE POWER REX 02        2.070102e+11                 0001    AbraÃ§adeira 16  Balance              PINTURA ABRACADEIRA SELIM 16/BALANCE       NaN
# 654     1.009302e+11                         BICICLETA BALANCE CALOI VERMELHA 02        2.070102e+11                 0001    AbraÃ§adeira 16  Balance              PINTURA ABRACADEIRA SELIM 16/BALANCE       NaN
# 659     1.009602e+11                                 BICICLETA BALANCE PRINCESAS        2.060102e+11                 0007      Garfo Balance  Balance         PINTURA GARFO DIANTEIRO ARO 12 ROSA CLA R       NaN
# 662     1.009602e+11                                 BICICLETA BALANCE PRINCESAS        2.070102e+11                 0001    AbraÃ§adeira 16  Balance              PINTURA ABRACADEIRA SELIM 16/BALANCE       NaN
# 670     1.009602e+11                                    BICICLETA BALANCE CARROS        2.070102e+11                 0001    AbraÃ§adeira 16  Balance              PINTURA ABRACADEIRA SELIM 16/BALANCE       NaN
# 678     1.009602e+11                             BICICLETA BALANCE SPIDER MAN 02        2.070102e+11                 0001    AbraÃ§adeira 16  Balance              PINTURA ABRACADEIRA SELIM 16/BALANCE       NaN
# 683     1.009602e+11                              BICICLETA BALANCE PRINCESAS 02        2.060102e+11                 0007      Garfo Balance  Balance         PINTURA GARFO DIANTEIRO ARO 12 ROSA CLA R       NaN
# 686     1.009602e+11                              BICICLETA BALANCE PRINCESAS 02        2.070102e+11                 0001    AbraÃ§adeira 16  Balance              PINTURA ABRACADEIRA SELIM 16/BALANCE       NaN
# 708     1.009702e+11                    BICICLETA BALANCE 12 RAIADA NATHOR LJ  2        2.060102e+11                 0018    GuidÃ£o Balance  Balance     PINTURA GUIDAO ARO 12 BALANCE RAIADA LA RANJA       NaN
# 709     1.009702e+11                    BICICLETA BALANCE 12 RAIADA NATHOR LJ  2        2.060102e+11                 0018     Quadro Balance  Balance     PINTURA QUADRO ARO 12 BALANCE RAIADA L ARANJA       NaN
# 710     1.009702e+11                    BICICLETA BALANCE 12 RAIADA NATHOR LJ  2        2.060102e+11                 0018      Garfo Balance  Balance  PINTURA GARFO DIANT ARO 12 BALANCE RAIA  LARANJA       NaN
# 718     1.009702e+11                          BICICLETA BALANCE 12 RAIADA AZUL 2        2.060102e+11                 0037     Quadro Balance  Balance     PINTURA QUADRO ARO 12 BALANCE RAIADA A ZUL AZ       NaN
# 728     1.009702e+11                          BICICLETA BALANCE 12 RAIADA ROSA 2        2.060102e+11                 0010     Quadro Balance  Balance   PINTURA QUADRO ARO 12 BALANCE RAIADA R OSA PINK       NaN
# 767     1.011102e+11      0001    KIT ABRACADEIRA SELIM ARO 16/20/BALAN CE PRETO        2.070102e+11                 0001    AbraÃ§adeira 16   Aro 16              PINTURA ABRACADEIRA SELIM 16/BALANCE       NaN
# 802     1.012002e+11                        BICICLETA ARO 20 APOLLO PRETO/LARANJ        2.071002e+11                 0018           Garfo 20   Aro 20            PINTURA GARFO DIANTEIRO ARO 20 LARANJA       NaN
# 803     1.012002e+11                        BICICLETA ARO 20 APOLLO PRETO/LARANJ        2.071002e+11                 0018         GuidÃ£o 20   Aro 20                     PINTURA GUIDAO ARO 20 LARANJA       NaN
# 824     1.012002e+11                        BICICLETA ARO 20 ANTONELLA TEEN ROSA        2.071002e+11                 0028         GuidÃ£o 20   Aro 20                   PINTURA GUIDAO ARO 20 ROSA (26)       NaN
# 825     1.012002e+11                        BICICLETA ARO 20 ANTONELLA TEEN ROSA        2.071002e+11                 0028           Garfo 20   Aro 20      PINTURA GARFO DIANT ARO 20 P/ PARALAMA  ROSA       NaN
# 827     1.012002e+11                        BICICLETA ARO 20 ANTONELLA TEEN ROSA        2.071002e+11                 0028          Quadro 20   Aro 20  PINTURA QUADRO ARO 20 FEM P/PARAL ABRA C ROSA ...      NaN
# 858     1.012002e+11                     BICICLETA ARO 20 APOLLO PRETO/LARANJ  2        2.071002e+11                 0018           Garfo 20   Aro 20            PINTURA GARFO DIANTEIRO ARO 20 LARANJA       NaN
# 859     1.012002e+11                     BICICLETA ARO 20 APOLLO PRETO/LARANJ  2        2.071002e+11                 0018         GuidÃ£o 20   Aro 20                     PINTURA GUIDAO ARO 20 LARANJA       NaN
# 915     1.012502e+11                                 BICICLETA ARO 16 SPIDER MAN        2.070102e+11                 0001    AbraÃ§adeira 16   Aro 16              PINTURA ABRACADEIRA SELIM 16/BALANCE       NaN
# 922     1.012502e+11                                     BICICLETA ARO 16 STITCH        2.070102e+11                 0001    AbraÃ§adeira 16   Aro 16              PINTURA ABRACADEIRA SELIM 16/BALANCE       NaN
# 929     1.012502e+11                              BICICLETA ARO 16 SPIDER MAN 02        2.070102e+11                 0001    AbraÃ§adeira 16   Aro 16              PINTURA ABRACADEIRA SELIM 16/BALANCE       NaN
# 938     1.012502e+11                                  BICICLETA ARO 16 STITCH 02        2.070102e+11                 0001    AbraÃ§adeira 16   Aro 16              PINTURA ABRACADEIRA SELIM 16/BALANCE       NaN
# 947     1.012502e+11                               BICICLETA ARO 16 PRINCESAS 02        2.070102e+11                 0001    AbraÃ§adeira 16   Aro 16              PINTURA ABRACADEIRA SELIM 16/BALANCE       NaN
# 956     1.012502e+11                          BICICLETA ARO 16 HOMEM DE FERRO 02        2.070102e+11                 0001    AbraÃ§adeira 16   Aro 16              PINTURA ABRACADEIRA SELIM 16/BALANCE       NaN
# 965     1.012502e+11                                  BICICLETA ARO 16 FROZEN 02        2.070102e+11                 0001    AbraÃ§adeira 16   Aro 16              PINTURA ABRACADEIRA SELIM 16/BALANCE       NaN
# 974     1.012502e+11                         BICICLETA ARO 16 CAPITAO AMERICA 02        2.070102e+11                 0001    AbraÃ§adeira 16   Aro 16              PINTURA ABRACADEIRA SELIM 16/BALANCE       NaN
# 986     1.012602e+11                                  BICICLETA ARO 12 PRINCESAS        2.060102e+11                 0007           Garfo 12   Aro 12         PINTURA GARFO DIANTEIRO ARO 12 ROSA CLA R       NaN
# 1010    1.013202e+11                            BICICLETA ARO 26 DEL MARE MARROM        2.071502e+11                 0055           Garfo 26   Aro 26             PINTURA GARFO DIANTEIRO ARO 26 MARROM       NaN
# 1011    1.013202e+11                            BICICLETA ARO 26 DEL MARE MARROM        2.071502e+11                 0055         GuidÃ£o 26   Aro 26                      PINTURA GUIDAO ARO 26 MARROM       NaN
# 1015    1.013202e+11                            BICICLETA ARO 26 DEL MARE MARROM        2.071502e+11                 0055          Quadro 26   Aro 26             PINTURA QUADRO ARO 26 DEL MARE MARROM       NaN
# 1049    1.013602e+11                                     BICICLETA ARO 16 BARBIE        2.070102e+11                 0017           Garfo 16   Aro 16        PINTURA GARFO DIANTEIRO ARO 16 ROSA POL IS       NaN
# 1050    1.013602e+11                                     BICICLETA ARO 16 BARBIE        2.070102e+11                 0017         GuidÃ£o 16   Aro 16                 PINTURA GUIDAO ARO 16 ROSA POLIES       NaN
# 1051    1.013602e+11                                     BICICLETA ARO 16 BARBIE        2.070102e+11                 0017          Quadro 16   Aro 16                 PINTURA QUADRO ARO 16 ROSA POLIES       NaN
# 1053    1.013602e+11                                     BICICLETA ARO 16 BARBIE        2.070102e+11                 0001    AbraÃ§adeira 16   Aro 16              PINTURA ABRACADEIRA SELIM 16/BALANCE       NaN
# 1062    1.013602e+11                                 BICICLETA ARO 16 HOT WHEELS        2.070102e+11                 0001    AbraÃ§adeira 16   Aro 16              PINTURA ABRACADEIRA SELIM 16/BALANCE       NaN
# 1079    1.013802e+11                                     BICICLETA ARO 26 BARBIE        2.071502e+11                 0007           Garfo 26   Aro 26               PINTURA GARFO DIANTEIRO ARO 26 ROSA       NaN
# 1080    1.013802e+11                                     BICICLETA ARO 26 BARBIE        2.071502e+11                 0007         GuidÃ£o 26   Aro 26                        PINTURA GUIDAO ARO 26 ROSA       NaN
# 1081    1.013802e+11                                     BICICLETA ARO 26 BARBIE        2.071502e+11                 0007          Quadro 26   Aro 26                        PINTURA QUADRO ARO 26 ROSA       NaN
# 1104    1.016102e+11                               BICICLETA ARO 16 GTS FEMININA        2.070102e+11                 0001    AbraÃ§adeira 16   Aro 16              PINTURA ABRACADEIRA SELIM 16/BALANCE       NaN
#
# --- AMOSTRA DAS CORES EXTRAÍDAS COM SUCESSO ---
#                          DESCRICAO_COMPONENTE     DESC_COR
# 0       PINTURA GARFO DIANTEIRO ARO 12 PRETO         preta
# 1                PINTURA GUIDAO ARO 12 PRETO         preta
# 2          PINTURA QUADRO ARO 12 MOD02 PRETO         preta
# 3                    PINTURA PEDIVELA BRANCO        branca
# 6      PINTURA GARFO DIANTEIRO ARO 12 BRANCO        branca
# 7               PINTURA GUIDAO ARO 12 BRANCO        branca
# 8   PINTURA QUADRO ARO 12 MOD02 ROSA ESCU RO   rosa escuro
# 9                    PINTURA PEDIVELA BRANCO        branca
# 13          PINTURA GUIDAO ARO 12 ROSA CLARO    rosa claro
# 14   PINTURA QUADRO ARO 12 MOD02 ROSA CLAR O    rosa claro
#
# Arquivo final com a coluna 'DESC_COR' foi salvo em: 'produtos_com_cores_mapeadas.csv'

# %%
import re

# --- 1. Definição do Mapeamento de Cores ---
# As regras são ordenadas da mais específica para a mais geral para garantir a precisão.
# Cada regra tem uma lista de variações (o que procurar) e um valor final (o que escrever).
# As variações são escritas sem espaços e em maiúsculas para uma correspondência robusta.
MAPA_DE_CORES = [
    # Regras mais específicas (múltiplas palavras) primeiro
    (['GRAFITEMETALICOFOSCO'], 'grafite metalico fosco'),
    (['AZULBRILHANTEFLEX'], 'azul brilhante flex'),
    (['PRETOGRAFITE'], 'tgic free preto grafite'),
    (['AMARELODOURADO'], 'amarelo dourado'),
    (['ROSAESCURO', 'ROSAESCU'], 'rosa escuro'),
    (['AZULESCURO'], 'azul escuro'),
    (['ROSACLARO', 'ROSACLAR'], 'rosa claro'),
    (['AZULCLARO', 'AZULCLARINHO'], 'azul claro'),
    (['ROSAMETALICO', 'ROSAMETALI'], 'rosa metalico aro 26'),
    (['PRETOFOSCO'], 'preto fosco'),
    (['ROSACHICLETE', 'ROSACHICL'], 'rosa chiclete'),
    (['CORALPINK', 'CORALPI'], 'coral pink'),
    (['AZULBEBE'], 'tgic free azul bebe'),
    (['ROSABEBE'], 'tgic free rosa bebe'),
    (['ROSAPEROL'], 'tgic free rosa perolizado'),
    # Regra de exceção de texto específico
    (['ABRACADEIRASELIM16/BALANCE'], 'preta'),
    # Regras de uma palavra ou menos específicas
    (['AZULFLEX'], 'tgic free azul flex'),
    (['LILAS-BANDEIRANTE', 'LILASBANDEIRANTE'], 'lilas - bandeirantes'), # Corrigido para corresponder à limpeza
    (['VERDEAQ', 'VERDEAQUA'], 'verde'),
    (['GRAFITE'], 'grafite metalico fosco'),
    (['BRANCO', 'BRANCA'], 'branca'),
    (['VERMELHO'], 'vermelho'),
    (['CINZA'], 'cinza'),
    (['LILAS'], 'lilas - bandeirantes'),
    (['ROSA'], 'rosa metalico aro 26'),
    (['VERDE'], 'verde'),
    (['COBRE'], 'preto fosco'),
    (['AMARELO'], 'amarelo dourado'),
    (['PRETO'], 'preta'),
    (['PRATA'], 'tgic free prata'),
    (['LARANJA'], 'laranja fosco')
]

def mapear_e_extrair_cor(descricao):
    """
    Extrai e padroniza a cor de uma descrição com base no MAPA_DE_CORES.
    A função lida apenas com strings que começam com 'PINTURA'.
    """
    if not isinstance(descricao, str) or not descricao.upper().startswith('PINTURA'):
        return np.nan

    # Limpa a string para uma comparação robusta: maiúsculas e sem espaços.
    # Ex: "PINTURA GARFO AZUL CLA RO" -> "PINTURAGARFOAZULCLARO"
    # Também remove hífens para casos como LILAS-BANDEIRANTE
    descricao_limpa = re.sub(r'[\s-]', '', descricao.upper())

    # Itera sobre o mapa ordenado
    for variacoes, cor_final in MAPA_DE_CORES:
        for variacao in variacoes:
            if variacao in descricao_limpa:
                return cor_final  # Retorna a primeira correspondência encontrada

    return 'nao_mapeado' # Retorna um marcador se nenhuma regra corresponder

# --- 2. Carregamento e Processamento do Arquivo ---
caminho_arquivo = r'../data/2025-06-13 - Estruturas - Produto x Tinta Pó - atualizado.csv'

try:
    df = pd.read_csv(caminho_arquivo, encoding='ISO-8859-1', sep=';')
except FileNotFoundError:
    print(f"Erro: Arquivo não encontrado no caminho: {caminho_arquivo}")
    exit()

df_processado = df.copy()

# Aplica a função para criar a nova coluna
df_processado['DESC_COR'] = df_processado['DESCRICAO_COMPONENTE'].apply(mapear_e_extrair_cor)


# --- 3. Validação e Relatório de Resultados ---
print("--- ANÁLISE DA EXTRAÇÃO DE CORES ---")

# Identifica as linhas que deveriam ter sido processadas (começam com PINTURA)
pintura_rows = df_processado['DESCRICAO_COMPONENTE'].str.upper().str.startswith('PINTURA', na=False)
total_pintura = pintura_rows.sum()

# Identifica as falhas: linhas de PINTURA que não foram mapeadas
falhas = df_processado[pintura_rows & (df_processado['DESC_COR'] == 'nao_mapeado')]
total_falhas = len(falhas)

# Identifica os sucessos
sucessos = df_processado.dropna(subset=['DESC_COR'])
# Remove as falhas marcadas da contagem de sucesso
total_sucessos = len(sucessos[sucessos['DESC_COR'] != 'nao_mapeado'])

print(f"\nTotal de linhas no arquivo: {len(df_processado)}")
print(f"Total de linhas de 'PINTURA' para processar: {total_pintura}")
print("-" * 40)
print(f"Sucessos na extração: {total_sucessos}")
print(f"Falhas (não mapeadas): {total_falhas}")
print("-" * 40)

# Apresenta as linhas que não puderam ser mapeadas para análise
if total_falhas > 0:
    print("\n>>> ATENÇÃO: As seguintes linhas de 'PINTURA' não foram mapeadas por nenhuma regra:")
    # Apresenta o conteúdo completo das linhas com falha
    with pd.option_context('display.max_rows', None, 'display.max_columns', None, 'display.width', 1000):
        print(falhas)
else:
    print("\n>>> SUCESSO: Todas as linhas de 'PINTURA' foram mapeadas com sucesso!")

# Mostra uma prévia das cores extraídas com sucesso
print("\n--- Amostra de Cores Extraídas com Sucesso ---")
print(sucessos[sucessos['DESC_COR'] != 'nao_mapeado'][['DESCRICAO_COMPONENTE', 'DESC_COR']].head(10).to_string())

# Remove o marcador 'nao_mapeado' e substitui por Nulo (NaN) para o arquivo final
df_processado['DESC_COR'].replace('nao_mapeado', np.nan, inplace=True)


# --- 4. Salvando o Resultado Final ---
caminho_saida = 'produtos_com_cores_mapeadas.csv'
df_processado.to_csv(caminho_saida, index=False, sep=';', encoding='ISO-8859-1')

print(f"\nArquivo processado foi salvo com sucesso em: {caminho_saida}")
# Out:
# --- ANÁLISE DA EXTRAÇÃO DE CORES ---
#
# Total de linhas no arquivo: 1142
# Total de linhas de 'PINTURA' para processar: 710
# ----------------------------------------
# Sucessos na extração: 686
# Falhas (não mapeadas): 24
# ----------------------------------------
#
# >>> ATENÇÃO: As seguintes linhas de 'PINTURA' não foram mapeadas por nenhuma regra:
#       CODIGO_PRODUTO Complemento                    DESCRICAO_PRODUTO  CODIGO_COMPONENTE Complemento_Componente    PINTURA_ITEM    LINHA                               DESCRICAO_COMPONENTE     DESC_COR
# 286     1.002902e+11               BICICLETA ARO 26 ANTONELLA PEROLA        2.071502e+11                 0056          Garfo 26   Aro 26             PINTURA GARFO DIANTEIRO ARO 26 PEROLA   nao_mapeado
# 287     1.002902e+11               BICICLETA ARO 26 ANTONELLA PEROLA        2.071502e+11                 0056        GuidÃ£o 26   Aro 26                      PINTURA GUIDAO ARO 26 PEROLA   nao_mapeado
# 288     1.002902e+11               BICICLETA ARO 26 ANTONELLA PEROLA        2.071502e+11                 0056         Quadro 26   Aro 26                      PINTURA QUADRO ARO 26 PEROLA   nao_mapeado
# 289     1.002902e+11               BICICLETA ARO 26 ANTONELLA PEROLA        2.071502e+11                 0055       Cestinha 26   Aro 26                   PINTURA CESTINHA ARO 26 MARROM    nao_mapeado
# 290     1.002902e+11               BICICLETA ARO 26 ANTONELLA PEROLA        2.071502e+11                 0055      Bagageiro 26   Aro 26        PINTURA BAGAGUEIRO TRASEIRO ARO 26 MAR ROM   nao_mapeado
# 322     1.002902e+11                    BICICLETA ARO 26 ANTHON AZUL        2.071502e+11                 0067          Garfo 26   Aro 26      PINTURA GARFO DIANTEIRO ARO 26 AZUL RAL 5019   nao_mapeado
# 323     1.002902e+11                    BICICLETA ARO 26 ANTHON AZUL        2.071502e+11                 0067        GuidÃ£o 26   Aro 26                PINTURA GUIDAO ARO 26 AZUL RAL5019   nao_mapeado
# 324     1.002902e+11                    BICICLETA ARO 26 ANTHON AZUL        2.071502e+11                 0067         Quadro 26   Aro 26                PINTURA QUADRO ARO 26 AZUL RAL5019   nao_mapeado
# 362     1.003602e+11               BICICLETA ARO 26 MOBHIS AZUL 5019        2.071502e+11                 0067        GuidÃ£o 26   Aro 26                PINTURA GUIDAO ARO 26 AZUL RAL5019   nao_mapeado
# 365     1.003602e+11               BICICLETA ARO 26 MOBHIS AZUL 5019        2.071502e+11                 0067          Garfo 26   Aro 26  PINTURA GARFO DIANTEIRO ARO 26 MOBHIS 0 1 AZUL...  nao_mapeado
# 366     1.003602e+11               BICICLETA ARO 26 MOBHIS AZUL 5019        2.071502e+11                 0067         Quadro 26   Aro 26        PINTURA QUADRO ARO 26 MOBHIS AZUL RAL5 019   nao_mapeado
# 370     1.004602e+11                     BICICLETA ARO 26 LOUIS AZUL        2.071502e+11                 0047          Garfo 26   Aro 26      PINTURA GARFO DIANTEIRO ARO 26 AZUL MAR INHO   nao_mapeado
# 371     1.004602e+11                     BICICLETA ARO 26 LOUIS AZUL        2.071502e+11                 0047        GuidÃ£o 26   Aro 26                PINTURA GUIDAO ARO 26 AZUL MARINHO   nao_mapeado
# 373     1.004602e+11                     BICICLETA ARO 26 LOUIS AZUL        2.071502e+11                 0047         Quadro 26   Aro 26  PINTURA QUADRO ARO 26 S/CAMBIO PE LATER AZUL M...  nao_mapeado
# 471     1.007102e+11                  BICICLETA ARO 26 INBRASUL AZUL        2.071502e+11                 0067          Garfo 26   Aro 26      PINTURA GARFO DIANTEIRO ARO 26 AZUL RAL 5019   nao_mapeado
# 472     1.007102e+11                  BICICLETA ARO 26 INBRASUL AZUL        2.071502e+11                 0067        GuidÃ£o 26   Aro 26                PINTURA GUIDAO ARO 26 AZUL RAL5019   nao_mapeado
# 476     1.007102e+11                  BICICLETA ARO 26 INBRASUL AZUL        2.071502e+11                 0067         Quadro 26   Aro 26            PINTURA QUADRO ARO 26 INBRASUL RAL5019   nao_mapeado
# 482     1.007402e+11               BICICLETA ARO 20 MOBHIS AZUL 5019        2.071002e+11                 0067          Garfo 20   Aro 20  PINTURA GARFO DIANTEIRO ARO 20 MOBHIS A ZUL 5019   nao_mapeado
# 483     1.007402e+11               BICICLETA ARO 20 MOBHIS AZUL 5019        2.071002e+11                 0067        GuidÃ£o 20   Aro 20            PINTURA GUIDAO ARO 20 MOBHIS AZUL 5019   nao_mapeado
# 484     1.007402e+11               BICICLETA ARO 20 MOBHIS AZUL 5019        2.071002e+11                 0067         Quadro 20   Aro 20     PINTURA QUADRO ARO 20 MOBHIS ABRAC AZU L 5019   nao_mapeado
# 718     1.009702e+11              BICICLETA BALANCE 12 RAIADA AZUL 2        2.060102e+11                 0037    Quadro Balance  Balance     PINTURA QUADRO ARO 12 BALANCE RAIADA A ZUL AZ   nao_mapeado
# 1010    1.013202e+11                BICICLETA ARO 26 DEL MARE MARROM        2.071502e+11                 0055          Garfo 26   Aro 26             PINTURA GARFO DIANTEIRO ARO 26 MARROM   nao_mapeado
# 1011    1.013202e+11                BICICLETA ARO 26 DEL MARE MARROM        2.071502e+11                 0055        GuidÃ£o 26   Aro 26                      PINTURA GUIDAO ARO 26 MARROM   nao_mapeado
# 1015    1.013202e+11                BICICLETA ARO 26 DEL MARE MARROM        2.071502e+11                 0055         Quadro 26   Aro 26             PINTURA QUADRO ARO 26 DEL MARE MARROM   nao_mapeado
#
# --- Amostra de Cores Extraídas com Sucesso ---
#                           DESCRICAO_COMPONENTE     DESC_COR
# 0        PINTURA GARFO DIANTEIRO ARO 12 PRETO         preta
# 1                 PINTURA GUIDAO ARO 12 PRETO         preta
# 2           PINTURA QUADRO ARO 12 MOD02 PRETO         preta
# 3                     PINTURA PEDIVELA BRANCO        branca
# 6       PINTURA GARFO DIANTEIRO ARO 12 BRANCO        branca
# 7                PINTURA GUIDAO ARO 12 BRANCO        branca
# 8    PINTURA QUADRO ARO 12 MOD02 ROSA ESCU RO   rosa escuro
# 9                     PINTURA PEDIVELA BRANCO        branca
# 12  PINTURA GARFO DIANTEIRO ARO 12 ROSA CLA R    rosa claro
# 13           PINTURA GUIDAO ARO 12 ROSA CLARO    rosa claro
#
# Arquivo processado foi salvo com sucesso em: produtos_com_cores_mapeadas.csv
# /tmp/ipykernel_1311524/841182885.py:119: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_processado['DESC_COR'].replace('nao_mapeado', np.nan, inplace=True)

# %%
df3 = pd.read_csv(
    r'../notebook/produtos_com_cores_mapeadas.csv',
    encoding='ISO-8859-1',
    sep=';'
)

df3.columns
# Out:
# Index(['CODIGO_PRODUTO', 'Complemento', 'DESCRICAO_PRODUTO',
#        'CODIGO_COMPONENTE', 'Complemento_Componente', 'PINTURA_ITEM', 'LINHA',
#        'DESCRICAO_COMPONENTE', 'DESC_COR'],
#       dtype='object')

# %%
df3
# Out:
#       CODIGO_PRODUTO Complemento                         DESCRICAO_PRODUTO  \
# 0       1.000102e+11                          BICICLETA ARO 12 BLACK 12 4
# 1       1.000102e+11                          BICICLETA ARO 12 BLACK 12 4
# 2       1.000102e+11                          BICICLETA ARO 12 BLACK 12 4
# 3       1.000102e+11                          BICICLETA ARO 12 BLACK 12 4
# 4       1.000102e+11                          BICICLETA ARO 12 BLACK 12 4
# ...              ...         ...                                       ...
# 1137    2.071002e+11      0002    RODA DIANTEIRA ARO 20 - 28 FUROS PRET O
# 1138    2.071002e+11      0002    RODA DIANTEIRA ARO 20 - 28 FUROS PRET O
# 1139    2.071002e+11      0001     RODA TRASEIRA ARO 20 COM MARCHA PT/P T
# 1140    2.071002e+11      0001     RODA TRASEIRA ARO 20 COM MARCHA PT/P T
# 1141             NaN         NaN                                       NaN
#
#       CODIGO_COMPONENTE Complemento_Componente PINTURA_ITEM   LINHA  \
# 0          2.060102e+11                 0001       Garfo 12  Aro 12
# 1          2.060102e+11                 0001     GuidÃ£o 12  Aro 12
# 2          2.060102e+11                 0001      Quadro 12  Aro 12
# 3          3.045102e+11                 0002    Pedivela 12  Aro 12
# 4          5.040101e+11                                 NaN     NaN
# ...                 ...                    ...          ...     ...
# 1137       2.071002e+11                 0001    Roda Aro 20  Aro 20
# 1138       5.040101e+11                                 NaN     NaN
# 1139       2.071002e+11                 0001    Roda Aro 20  Aro 20
# 1140       5.040101e+11                                 NaN     NaN
# 1141                NaN                    NaN    Quadro 12     NaN
#
#                        DESCRICAO_COMPONENTE DESC_COR
# 0     PINTURA GARFO DIANTEIRO ARO 12 PRETO     preta
# 1              PINTURA GUIDAO ARO 12 PRETO     preta
# 2        PINTURA QUADRO ARO 12 MOD02 PRETO     preta
# 3                  PINTURA PEDIVELA BRANCO    branca
# 4                       TINTA EM PO BRANCA       NaN
# ...                                     ...      ...
# 1137               PINTURA DO ARO 20 PRETO     preta
# 1138                     TINTA EM PO PRETA       NaN
# 1139               PINTURA DO ARO 20 PRETO     preta
# 1140                     TINTA EM PO PRETA       NaN
# 1141                                    NaN      NaN
#
# [1142 rows x 9 columns]

# %%
df4 = pd.read_csv(
    r'../notebook/dsc_cores.csv',
    encoding='utf-8-sig',  # <-- corrige o problema do BOM
    sep=','
)
df4.columns
# Out:
# Index(['CODIGO_COR', 'DESCRICAO', 'QUANTIDADE', 'VARIACOES_APELIDO',
#        'DESC_COR'],
#       dtype='object')

# %%
# Renomear a coluna
df4 = df4.rename(columns={'DESCRICAO': 'DESCRICAO_COR'})

# Salvar como CSV
df4.to_csv('Planilha_Cores.csv', index=False, encoding='utf-8-sig')

# Salvar como Excel (XLSX)
df4.to_excel('Planilha_Cores.xlsx', index=False)

# %%
df5 = pd.read_csv(
    r'../notebook/Planilha_Cores.csv',
    encoding='utf-8-sig',  # <-- corrige o problema do BOM
    sep=','
)
df5.columns
# Out:
# Index(['CODIGO_COR', 'DESCRICAO_COR', 'QUANTIDADE', 'VARIACOES_APELIDO',
#        'DESC_COR'],
#       dtype='object')

# %%
# --- 1. Carregamento dos Arquivos ---
# Carrega o arquivo de produtos com as cores já mapeadas
try:
    df3 = pd.read_csv(
        r'../notebook/produtos_com_cores_mapeadas.csv',
        encoding='ISO-8859-1',
        sep=';'
    )
except FileNotFoundError:
    print("Erro: Arquivo 'produtos_com_cores_mapeadas.csv' não encontrado. Verifique o caminho.")
    exit()

# Carrega o arquivo de referência de cores (seu "de-para")
try:
    df5 = pd.read_csv(
        r'../notebook/Planilha_Cores.csv',
        encoding='utf-8-sig',
        sep=','
    )
except FileNotFoundError:
    print("Erro: Arquivo 'Planilha_Cores.csv' não encontrado. Verifique o caminho.")
    exit()


# --- 2. Preparação para o Merge ---
# Seleciona apenas as colunas necessárias do df5 para o merge.
# Isso evita adicionar colunas duplicadas ou desnecessárias.
colunas_para_trazer = ['DESC_COR', 'CODIGO_COR', 'DESCRICAO_COR']
df5_lookup = df5[colunas_para_trazer]

# Remove possíveis duplicatas na chave de merge em df5 para evitar multiplicação de linhas.
# Garante que cada 'DESC_COR' da planilha de cores seja única.
df5_lookup = df5_lookup.drop_duplicates(subset=['DESC_COR'])

print("Arquivos carregados com sucesso. Iniciando o merge...")
print(f"Total de linhas em df3 (antes do merge): {len(df3)}")
print(f"Total de cores únicas para consulta em df5: {len(df5_lookup)}")
print("-" * 50)


# --- 3. Execução do Merge ---
# 'how='left'' garante que todas as linhas de df3 sejam mantidas.
# 'on='DESC_COR'' especifica a coluna chave para a união.
df_final = pd.merge(df3, df5_lookup, on='DESC_COR', how='left')


# --- 4. Validação e Análise do Resultado ---
print("Merge concluído!")
print(f"Total de linhas em df_final (depois do merge): {len(df_final)}")

# Validação: Verifica quantas linhas do df3 tinham uma cor que foi encontrada no df5
total_com_cor = df_final['DESC_COR'].notna().sum()
total_mapeado_com_codigo = df_final['CODIGO_COR'].notna().sum()

print(f"Linhas em df_final com uma 'DESC_COR': {total_com_cor}")
print(f"Dessas, {total_mapeado_com_codigo} encontraram um 'CODIGO_COR' correspondente.")

if total_com_cor > total_mapeado_com_codigo:
    print(f"Atenção: {total_com_cor - total_mapeado_com_codigo} cores de df3 não foram encontradas na Planilha_Cores.csv.")


# Mostra as colunas do novo DataFrame e uma prévia do resultado
print("\nColunas do DataFrame final:")
print(df_final.columns)

print("\nAmostra do resultado com as novas colunas:")
# Seleciona colunas relevantes para a visualização da amostra
colunas_amostra = ['CODIGO_PRODUTO', 'DESCRICAO_COMPONENTE', 'DESC_COR', 'CODIGO_COR', 'DESCRICAO_COR']
print(df_final[colunas_amostra].head(10).to_string())


# --- 5. Salvando o Resultado ---
caminho_saida = 'produtos_com_codigo_cor_final.csv'
df_final.to_csv(caminho_saida, index=False, sep=';', encoding='ISO-8859-1')

print(f"\nArquivo final salvo com sucesso em: {caminho_saida}")
# Out:
# Arquivos carregados com sucesso. Iniciando o merge...
# Total de linhas em df3 (antes do merge): 1142
# Total de cores únicas para consulta em df5: 29
# --------------------------------------------------
# Merge concluído!
# Total de linhas em df_final (depois do merge): 1142
# Linhas em df_final com uma 'DESC_COR': 686
# Dessas, 658 encontraram um 'CODIGO_COR' correspondente.
# Atenção: 28 cores de df3 não foram encontradas na Planilha_Cores.csv.
#
# Colunas do DataFrame final:
# Index(['CODIGO_PRODUTO', 'Complemento', 'DESCRICAO_PRODUTO',
#        'CODIGO_COMPONENTE', 'Complemento_Componente', 'PINTURA_ITEM', 'LINHA',
#        'DESCRICAO_COMPONENTE', 'DESC_COR', 'CODIGO_COR', 'DESCRICAO_COR'],
#       dtype='object')
#
# Amostra do resultado com as novas colunas:
#    CODIGO_PRODUTO                       DESCRICAO_COMPONENTE     DESC_COR    CODIGO_COR            DESCRICAO_COR
# 0    1.000102e+11      PINTURA GARFO DIANTEIRO ARO 12 PRETO         preta  5.040101e+11        TINTA EM PO PRETA
# 1    1.000102e+11               PINTURA GUIDAO ARO 12 PRETO         preta  5.040101e+11        TINTA EM PO PRETA
# 2    1.000102e+11         PINTURA QUADRO ARO 12 MOD02 PRETO         preta  5.040101e+11        TINTA EM PO PRETA
# 3    1.000102e+11                   PINTURA PEDIVELA BRANCO        branca  5.040101e+11       TINTA EM PO BRANCA
# 4    1.000102e+11                        TINTA EM PO BRANCA           NaN           NaN                      NaN
# 5    1.000102e+11                         TINTA EM PO PRETA           NaN           NaN                      NaN
# 6    1.000102e+11     PINTURA GARFO DIANTEIRO ARO 12 BRANCO        branca  5.040101e+11       TINTA EM PO BRANCA
# 7    1.000102e+11              PINTURA GUIDAO ARO 12 BRANCO        branca  5.040101e+11       TINTA EM PO BRANCA
# 8    1.000102e+11  PINTURA QUADRO ARO 12 MOD02 ROSA ESCU RO   rosa escuro  5.040101e+11  TINTA EM PO ROSA ESCURO
# 9    1.000102e+11                   PINTURA PEDIVELA BRANCO        branca  5.040101e+11       TINTA EM PO BRANCA
#
# Arquivo final salvo com sucesso em: produtos_com_codigo_cor_final.csv

# %%
df6 = pd.read_csv(
    r'/home/lucala/HUB AI/Nathor/SPRINT III - nathor/data/dados.csv',
    encoding='ISO-8859-1',
    sep=';'
)

df6.columns
# Out:
# Index(['Componente', 'Linha', 'PeÃ§as p/ gancheira', 'EspaÃ§amento', 'PINOS ',
#        'Estoque Gancheiras', 'Altura', 'Largura', 'Peso (kg)'],
#       dtype='object')

# %%
df7 = pd.read_csv(
    r'/home/lucala/HUB AI/Nathor/SPRINT III - nathor/notebook/produtos_com_codigo_cor_final.csv',
    encoding='ISO-8859-1',
    sep=';'
)

df7.columns

# --- 2. Visualização das Colunas Originais ---
print("Colunas antes da alteração:")
print(df6.columns)
print("-" * 50)


# --- 3. Renomeando a Coluna ---
# O método rename é usado com um dicionário: {'nome_antigo': 'nome_novo'}
# inplace=True modifica o DataFrame diretamente, sem precisar de reatribuição (df6 = ...)
df7.rename(columns={'PINTURA_ITEM': 'Componente'}, inplace=True)


# --- 4. Verificação e Visualização do Resultado ---
print("Coluna renomeada com sucesso!")
print("\nColunas após a alteração:")
print(df7.columns)
print("-" * 50)

# Mostra as primeiras linhas do DataFrame com a coluna já renomeada
print("\nAmostra do DataFrame com a coluna 'Componente':")
colunas_para_ver = ['CODIGO_PRODUTO', 'Componente', 'DESCRICAO_COMPONENTE', 'DESC_COR']
print(df7[colunas_para_ver].head())
# Out:
# Colunas antes da alteração:
# Index(['Componente', 'Linha', 'PeÃ§as p/ gancheira', 'EspaÃ§amento', 'PINOS ',
#        'Estoque Gancheiras', 'Altura', 'Largura', 'Peso (kg)'],
#       dtype='object')
# --------------------------------------------------
# Coluna renomeada com sucesso!
#
# Colunas após a alteração:
# Index(['CODIGO_PRODUTO', 'Complemento', 'DESCRICAO_PRODUTO',
#        'CODIGO_COMPONENTE', 'Complemento_Componente', 'Componente', 'LINHA',
#        'DESCRICAO_COMPONENTE', 'DESC_COR', 'CODIGO_COR', 'DESCRICAO_COR'],
#       dtype='object')
# --------------------------------------------------
#
# Amostra do DataFrame com a coluna 'Componente':
#    CODIGO_PRODUTO   Componente                   DESCRICAO_COMPONENTE DESC_COR
# 0    1.000102e+11     Garfo 12  PINTURA GARFO DIANTEIRO ARO 12 PRETO     preta
# 1    1.000102e+11   GuidÃ£o 12           PINTURA GUIDAO ARO 12 PRETO     preta
# 2    1.000102e+11    Quadro 12     PINTURA QUADRO ARO 12 MOD02 PRETO     preta
# 3    1.000102e+11  Pedivela 12               PINTURA PEDIVELA BRANCO    branca
# 4    1.000102e+11          NaN                    TINTA EM PO BRANCA       NaN

# %%
df7.columns
# Out:
# Index(['CODIGO_PRODUTO', 'Complemento', 'DESCRICAO_PRODUTO',
#        'CODIGO_COMPONENTE', 'Complemento_Componente', 'Componente', 'LINHA',
#        'DESCRICAO_COMPONENTE', 'DESC_COR', 'CODIGO_COR', 'DESCRICAO_COR'],
#       dtype='object')

# %%
df6.columns
# Out:
# Index(['Componente', 'Linha', 'PeÃ§as p/ gancheira', 'EspaÃ§amento', 'PINOS ',
#        'Estoque Gancheiras', 'Altura', 'Largura', 'Peso (kg)'],
#       dtype='object')

# %%
# --- 1. Preparação para o Merge ---

# Para evitar confusão com colunas de mesmo nome (como 'LINHA'),
# vamos selecionar apenas as colunas de df6 que queremos adicionar.
# Vamos remover a coluna 'LINHA' de df6 para não criar 'LINHA_x' e 'LINHA_y'.
# Se a coluna 'Linha' de df6 for importante, podemos renomeá-la antes.
colunas_para_trazer = df6.columns.drop('LINHA', errors='ignore') # 'errors=ignore' evita erro se a coluna não existir
df6_lookup = df6[colunas_para_trazer]

# Remove duplicatas na chave de merge para garantir uma união limpa
df6_lookup = df6_lookup.drop_duplicates(subset=['Componente'])

print("DataFrames prontos para o merge.")
print(f"Total de linhas em df7 (principal): {len(df7)}")
print(f"Total de Componentes únicos para consulta em df6: {len(df6_lookup)}")
print("-" * 50)


# --- 2. Execução do Merge ---
# 'how='left'' garante que todas as linhas de df7 sejam mantidas.
# 'on='Componente'' especifica a coluna chave.
df_final_merged = pd.merge(df7, df6_lookup, on='Componente', how='left')


# --- 3. Validação e Análise das Linhas que Ficaram de Fora ---
print("Merge concluído!")

# Para encontrar as linhas que "ficaram de fora", vamos checar onde uma das
# colunas que veio de df6 está nula, mas o 'Componente' em si não era nulo.
# Usaremos uma coluna que com certeza existe em df6 e não em df7, por exemplo 'Peso (kg)'.
# Se 'Peso (kg)' não for uma boa coluna de verificação, ajuste para outra.
coluna_verificacao = 'Peso (kg)' # Ajuste se necessário

# Condições para identificar as linhas que não tiveram match:
# 1. O componente existe em df7 (não é nulo).
# 2. A coluna de verificação (que veio de df6) está nula após o merge.
linhas_sem_match = df_final_merged[
    df_final_merged['Componente'].notna() & df_final_merged[coluna_verificacao].isna()
]

total_sem_match = len(linhas_sem_match)

if total_sem_match > 0:
    print(f"\n>>> ATENÇÃO: {total_sem_match} linhas de df7 não encontraram um 'Componente' correspondente em df6.")
    print("Abaixo estão os dados completos dessas linhas para sua análise:")
    # Mostra todas as colunas das linhas que falharam no merge
    with pd.option_context('display.max_rows', None, 'display.max_columns', None, 'display.width', 120):
        print(linhas_sem_match)
else:
    print("\n>>> SUCESSO: Todas as linhas com 'Componente' em df7 encontraram uma correspondência em df6.")


# --- 4. Visualização do Resultado e Salvamento ---
print("\nColunas do DataFrame final:")
print(df_final_merged.columns)

print("\nAmostra do DataFrame final com os dados unidos:")
print(df_final_merged.head().to_string())

# Opcional: Salvar o resultado final em um novo arquivo CSV
caminho_saida = 'dsc.csv'
df_final_merged.to_csv(caminho_saida, index=False, sep=';', encoding='ISO-8859-1')

print(f"\nArquivo final salvo com sucesso em: {caminho_saida}")
# Out:
# DataFrames prontos para o merge.
# Total de linhas em df7 (principal): 1142
# Total de Componentes únicos para consulta em df6: 36
# --------------------------------------------------
# Merge concluído!
#
# >>> ATENÇÃO: 30 linhas de df7 não encontraram um 'Componente' correspondente em df6.
# Abaixo estão os dados completos dessas linhas para sua análise:
#       CODIGO_PRODUTO Complemento                                DESCRICAO_PRODUTO  CODIGO_COMPONENTE  \
# 258     1.002802e+11                    BICICLETA ARO 16 BTWIN CRUISER 500 202 2        2.070102e+11
# 269     1.002802e+11                  BICICLETA ARO 16 BTWIN 500 PRATA/VERM ELHA        2.070102e+11
# 279     1.002802e+11                          BICICLETA ARO 16 BTWIN 500 AMARELA        2.070102e+11
# 288     1.002902e+11                           BICICLETA ARO 26 ANTONELLA PEROLA        2.071502e+11
# 297     1.002902e+11                             BICICLETA ARO 26 ANTONELLA ROSA        2.071502e+11
# 306     1.002902e+11                      BICICLETA ARO 26 ANTONELLA VERDE AQU A        2.071502e+11
# 315     1.002902e+11                               BICICLETA ARO 26 ANTHON CINZA        2.071502e+11
# 324     1.002902e+11                                BICICLETA ARO 26 ANTHON AZUL        2.071502e+11
# 342     1.003302e+11                             BICICLETA ARO 26 VETTER AMARELA        2.071502e+11
# 366     1.003602e+11                           BICICLETA ARO 26 MOBHIS AZUL 5019        2.071502e+11
# 373     1.004602e+11                                 BICICLETA ARO 26 LOUIS AZUL        2.071502e+11
# 380     1.004602e+11                             BICICLETA ARO 26 LIS CORAL PINK        2.071502e+11
# 476     1.007102e+11                              BICICLETA ARO 26 INBRASUL AZUL        2.071502e+11
# 481     1.007402e+11                           BICICLETA ARO 20 MOBHIS AZUL 5019        2.071002e+11
# 793     1.011502e+11      0001                    ARO DIANTEIRO 20 MONTADO PRETO        2.071002e+11
# 795     1.011502e+11      0001                 ARO TRASEIRO ARO 20 MONTADO PRETO        2.071002e+11
# 797     1.011502e+11      0002      ARO TRASEIRO ARO 20 MONTADO C/ MARC HA PRETO        2.071002e+11
# 818     1.012002e+11                      BICICLETA ARO 20 ANTONELLA TEEN VERD E        2.071002e+11
# 826     1.012002e+11                        BICICLETA ARO 20 ANTONELLA TEEN ROSA        2.071002e+11
# 888     1.012102e+11                         BICICLETA ARO 20 BTWIN ORIGINAL 500        2.071002e+11
# 907     1.012102e+11                     BICICLETA ARO 20 BTWIN ST 500 MASC 2022        2.071002e+11
# 1015    1.013202e+11                            BICICLETA ARO 26 DEL MARE MARROM        2.071502e+11
# 1081    1.013802e+11                                     BICICLETA ARO 26 BARBIE        2.071502e+11
# 1127    2.070102e+11      0001      RODA TRASEIRA ARO 16 PRETO - 20 FUROS RAIADO        2.070102e+11
# 1129    2.070102e+11      0001    RODA DIANTEIRA ARO 16 PRETO - 20 FURO S RAIADO        2.070102e+11
# 1131    2.071002e+11      0001             RODA TRASEIRA ARO 20 PRETO - 28 FUROS        2.071002e+11
# 1133    2.071002e+11      0002             RODA TRASEIRA ARO 20 - 28 FUROS PRETO        2.071002e+11
# 1135    2.071002e+11      0001                       RODA DIANTEIRA ARO 20 PT/PT        2.071002e+11
# 1137    2.071002e+11      0002           RODA DIANTEIRA ARO 20 - 28 FUROS PRET O        2.071002e+11
# 1139    2.071002e+11      0001            RODA TRASEIRA ARO 20 COM MARCHA PT/P T        2.071002e+11
#
#      Complemento_Componente            Componente   LINHA                               DESCRICAO_COMPONENTE  \
# 258                  0001             Roda Aro 16  Aro 16                  PINTURA DO ARO 16 PRETO 20 FUROS
# 269                  0001             Roda Aro 16  Aro 16                  PINTURA DO ARO 16 PRETO 20 FUROS
# 279                  0001             Roda Aro 16  Aro 16                  PINTURA DO ARO 16 PRETO 20 FUROS
# 288                  0056               Quadro 26  Aro 26                      PINTURA QUADRO ARO 26 PEROLA
# 297                  0007               Quadro 26  Aro 26                        PINTURA QUADRO ARO 26 ROSA
# 306                  0043               Quadro 26  Aro 26                       PINTURA QUADRO ARO 26 VERDE
# 315                  0016               Quadro 26  Aro 26                       PINTURA QUADRO ARO 26 CINZA
# 324                  0067               Quadro 26  Aro 26                PINTURA QUADRO ARO 26 AZUL RAL5019
# 342                  0003               Quadro 26  Aro 26              PINTURA QUADRO ARO 26 VETTER AMARELO
# 366                  0067               Quadro 26  Aro 26        PINTURA QUADRO ARO 26 MOBHIS AZUL RAL5 019
# 373                  0047               Quadro 26  Aro 26  PINTURA QUADRO ARO 26 S/CAMBIO PE LATER AZUL M...
# 380                  0062               Quadro 26  Aro 26  PINTURA QUADRO ARO 26 S/CAMBIO PE LATER CORAL ...
# 476                  0067               Quadro 26  Aro 26            PINTURA QUADRO ARO 26 INBRASUL RAL5019
# 481                  0009    Paralama Traseiro 20  Aro 20         PINTURA PARALAMAS DIAN/TRAS ARO 20 CINZ A
# 793                  0001             Roda Aro 20  Aro 20                           PINTURA DO ARO 20 PRETO
# 795                  0001             Roda Aro 20  Aro 20                           PINTURA DO ARO 20 PRETO
# 797                  0001             Roda Aro 20  Aro 20                           PINTURA DO ARO 20 PRETO
# 818                  0002    Paralama Traseiro 20  Aro 20        PINTURA PARALAMAS DIAN/TRAS ARO 20 BRA NCO
# 826                  0009    Paralama Traseiro 20  Aro 20         PINTURA PARALAMAS DIAN/TRAS ARO 20 CINZ A
# 888                  0043    Paralama Traseiro 20  Aro 20    PINTURA PARALAMAS DIAN/TRAS ARO 20 VER DE AQUA
# 907                  0001             Roda Aro 20  Aro 20                           PINTURA DO ARO 20 PRETO
# 1015                 0055               Quadro 26  Aro 26             PINTURA QUADRO ARO 26 DEL MARE MARROM
# 1081                 0007               Quadro 26  Aro 26                        PINTURA QUADRO ARO 26 ROSA
# 1127                 0001             Roda Aro 16  Aro 16                  PINTURA DO ARO 16 PRETO 20 FUROS
# 1129                 0001             Roda Aro 16  Aro 16                  PINTURA DO ARO 16 PRETO 20 FUROS
# 1131                 0001             Roda Aro 20  Aro 20                           PINTURA DO ARO 20 PRETO
# 1133                 0001             Roda Aro 20  Aro 20                           PINTURA DO ARO 20 PRETO
# 1135                 0001             Roda Aro 20  Aro 20                           PINTURA DO ARO 20 PRETO
# 1137                 0001             Roda Aro 20  Aro 20                           PINTURA DO ARO 20 PRETO
# 1139                 0001             Roda Aro 20  Aro 20                           PINTURA DO ARO 20 PRETO
#
#                   DESC_COR    CODIGO_COR                         DESCRICAO_COR   Linha  PeÃ§as p/ gancheira  \
# 258                  preta  5.040101e+11                     TINTA EM PO PRETA  Aro 16                 16.0
# 269                  preta  5.040101e+11                     TINTA EM PO PRETA  Aro 16                 16.0
# 279                  preta  5.040101e+11                     TINTA EM PO PRETA  Aro 16                 16.0
# 288                    NaN           NaN                                   NaN  Aro 26                  1.0
# 297   rosa metalico aro 26  5.040101e+11  TINTA POLIESTER ROSA METALICO ARO 26  Aro 26                  1.0
# 306                  verde           NaN                                   NaN  Aro 26                  1.0
# 315                  cinza  5.040101e+11                     TINTA EM PO CINZA  Aro 26                  1.0
# 324                    NaN           NaN                                   NaN  Aro 26                  1.0
# 342        amarelo dourado  5.040101e+11           TINTA EM PO AMARELO DOURADO  Aro 26                  1.0
# 366                    NaN           NaN                                   NaN  Aro 26                  1.0
# 373                    NaN           NaN                                   NaN  Aro 26                  1.0
# 380             coral pink  5.040101e+11                TINTA EM PO CORAL PINK  Aro 26                  1.0
# 476                    NaN           NaN                                   NaN  Aro 26                  1.0
# 481                  cinza  5.040101e+11                     TINTA EM PO CINZA  Aro 20                  6.0
# 793                  preta  5.040101e+11                     TINTA EM PO PRETA  Aro 20                 16.0
# 795                  preta  5.040101e+11                     TINTA EM PO PRETA  Aro 20                 16.0
# 797                  preta  5.040101e+11                     TINTA EM PO PRETA  Aro 20                 16.0
# 818                 branca  5.040101e+11                    TINTA EM PO BRANCA  Aro 20                  6.0
# 826                  cinza  5.040101e+11                     TINTA EM PO CINZA  Aro 20                  6.0
# 888                  verde           NaN                                   NaN  Aro 20                  6.0
# 907                  preta  5.040101e+11                     TINTA EM PO PRETA  Aro 20                 16.0
# 1015                   NaN           NaN                                   NaN  Aro 26                  1.0
# 1081  rosa metalico aro 26  5.040101e+11  TINTA POLIESTER ROSA METALICO ARO 26  Aro 26                  1.0
# 1127                 preta  5.040101e+11                     TINTA EM PO PRETA  Aro 16                 16.0
# 1129                 preta  5.040101e+11                     TINTA EM PO PRETA  Aro 16                 16.0
# 1131                 preta  5.040101e+11                     TINTA EM PO PRETA  Aro 20                 16.0
# 1133                 preta  5.040101e+11                     TINTA EM PO PRETA  Aro 20                 16.0
# 1135                 preta  5.040101e+11                     TINTA EM PO PRETA  Aro 20                 16.0
# 1137                 preta  5.040101e+11                     TINTA EM PO PRETA  Aro 20                 16.0
# 1139                 preta  5.040101e+11                     TINTA EM PO PRETA  Aro 20                 16.0
#
#      EspaÃ§amento  PINOS   Estoque Gancheiras Altura Largura Peso (kg)
# 258          1,20     2.0                 NaN    NaN     NaN       NaN
# 269          1,20     2.0                 NaN    NaN     NaN       NaN
# 279          1,20     2.0                 NaN    NaN     NaN       NaN
# 288          1,00     NaN                 NaN    NaN     NaN       NaN
# 297          1,00     NaN                 NaN    NaN     NaN       NaN
# 306          1,00     NaN                 NaN    NaN     NaN       NaN
# 315          1,00     NaN                 NaN    NaN     NaN       NaN
# 324          1,00     NaN                 NaN    NaN     NaN       NaN
# 342          1,00     NaN                 NaN    NaN     NaN       NaN
# 366          1,00     NaN                 NaN    NaN     NaN       NaN
# 373          1,00     NaN                 NaN    NaN     NaN       NaN
# 380          1,00     NaN                 NaN    NaN     NaN       NaN
# 476          1,00     NaN                 NaN    NaN     NaN       NaN
# 481          1,20     2.0                 NaN    NaN     NaN       NaN
# 793          0,80     NaN                 NaN    NaN     NaN       NaN
# 795          0,80     NaN                 NaN    NaN     NaN       NaN
# 797          0,80     NaN                 NaN    NaN     NaN       NaN
# 818          1,20     2.0                 NaN    NaN     NaN       NaN
# 826          1,20     2.0                 NaN    NaN     NaN       NaN
# 888          1,20     2.0                 NaN    NaN     NaN       NaN
# 907          0,80     NaN                 NaN    NaN     NaN       NaN
# 1015         1,00     NaN                 NaN    NaN     NaN       NaN
# 1081         1,00     NaN                 NaN    NaN     NaN       NaN
# 1127         1,20     2.0                 NaN    NaN     NaN       NaN
# 1129         1,20     2.0                 NaN    NaN     NaN       NaN
# 1131         0,80     NaN                 NaN    NaN     NaN       NaN
# 1133         0,80     NaN                 NaN    NaN     NaN       NaN
# 1135         0,80     NaN                 NaN    NaN     NaN       NaN
# 1137         0,80     NaN                 NaN    NaN     NaN       NaN
# 1139         0,80     NaN                 NaN    NaN     NaN       NaN
#
# Colunas do DataFrame final:
# Index(['CODIGO_PRODUTO', 'Complemento', 'DESCRICAO_PRODUTO',
#        'CODIGO_COMPONENTE', 'Complemento_Componente', 'Componente', 'LINHA',
#        'DESCRICAO_COMPONENTE', 'DESC_COR', 'CODIGO_COR', 'DESCRICAO_COR',
#        'Linha', 'PeÃ§as p/ gancheira', 'EspaÃ§amento', 'PINOS ',
#        'Estoque Gancheiras', 'Altura', 'Largura', 'Peso (kg)'],
#       dtype='object')
#
# Amostra do DataFrame final com os dados unidos:
#    CODIGO_PRODUTO Complemento             DESCRICAO_PRODUTO  CODIGO_COMPONENTE Complemento_Componente   Componente   LINHA                   DESCRICAO_COMPONENTE DESC_COR    CODIGO_COR       DESCRICAO_COR   Linha  PeÃ§as p/ gancheira EspaÃ§amento  PINOS   Estoque Gancheiras Altura Largura Peso (kg)
# 0    1.000102e+11              BICICLETA ARO 12 BLACK 12 4        2.060102e+11                 0001       Garfo 12  Aro 12  PINTURA GARFO DIANTEIRO ARO 12 PRETO     preta  5.040101e+11   TINTA EM PO PRETA  Aro 12                 24.0         1,20     1.0               114.0   1,75    73c      5,400
# 1    1.000102e+11              BICICLETA ARO 12 BLACK 12 4        2.060102e+11                 0001     GuidÃ£o 12  Aro 12           PINTURA GUIDAO ARO 12 PRETO     preta  5.040101e+11   TINTA EM PO PRETA  Aro 12                 26.0         1,20     1.0               116.0   1,94     23c     2,480
# 2    1.000102e+11              BICICLETA ARO 12 BLACK 12 4        2.060102e+11                 0001      Quadro 12  Aro 12     PINTURA QUADRO ARO 12 MOD02 PRETO     preta  5.040101e+11   TINTA EM PO PRETA  Aro 12                  8.0         0,90     1.0               166.0   1,75     30c     2,300
# 3    1.000102e+11              BICICLETA ARO 12 BLACK 12 4        3.045102e+11                 0002    Pedivela 12  Aro 12               PINTURA PEDIVELA BRANCO    branca  5.040101e+11  TINTA EM PO BRANCA  Aro 12                 44.0         0,80     1.0               150.0   1,53     60c     2,500
# 4    1.000102e+11              BICICLETA ARO 12 BLACK 12 4        5.040101e+11                                 NaN     NaN                    TINTA EM PO BRANCA       NaN           NaN                 NaN     NaN                  NaN          NaN     NaN                 NaN    NaN     NaN       NaN
#
# Arquivo final salvo com sucesso em: dsc.csv

# %%
df_final_merged.columns
# Out:
# Index(['CODIGO_PRODUTO', 'Complemento', 'DESCRICAO_PRODUTO',
#        'CODIGO_COMPONENTE', 'Complemento_Componente', 'Componente', 'LINHA',
#        'DESCRICAO_COMPONENTE', 'DESC_COR', 'CODIGO_COR', 'DESCRICAO_COR',
#        'Linha', 'PeÃ§as p/ gancheira', 'EspaÃ§amento', 'PINOS ',
#        'Estoque Gancheiras', 'Altura', 'Largura', 'Peso (kg)'],
#       dtype='object')

# %%
import pandas as pd
import numpy as np

# --- 1. Carregamento do Arquivo ---
# Presumindo que você já tem o DataFrame 'df_final_merged' carregado.
# Se precisar carregar do arquivo:
caminho_arquivo = r'/home/lucala/HUB AI/Nathor/SPRINT III - nathor/notebook/dsc.csv'
try:
    df = pd.read_csv(caminho_arquivo, encoding='ISO-8859-1', sep=';')
except FileNotFoundError:
    print(f"Erro: Arquivo não encontrado no caminho: {caminho_arquivo}")
    exit()


# --- 2. Limpeza e Conversão das Colunas de Dimensão ---
print("Iniciando limpeza e conversão das colunas 'Altura' e 'Largura'...")

# Lista das colunas que precisamos converter
colunas_dimensao = ['Altura', 'Largura']

for col in colunas_dimensao:
    # Cria uma nova coluna numérica para não alterar a original
    col_numerica = f'{col}_numerica'
    
    # Converte a coluna para string para poder usar o .str.replace
    # Substitui a vírgula decimal por ponto decimal
    df[col_numerica] = df[col].astype(str).str.replace(',', '.', regex=False)
    
    # Converte para tipo numérico. 'errors='coerce'' transforma qualquer valor
    # que não possa ser convertido (ex: texto "N/A") em Nulo (NaN).
    df[col_numerica] = pd.to_numeric(df[col_numerica], errors='coerce')

# Preenche os valores nulos com 0 para que não atrapalhem a multiplicação.
# Se uma dimensão for nula, a área será 0.
df['Altura_numerica'].fillna(0, inplace=True)
df['Largura_numerica'].fillna(0, inplace=True)

print("\nTipos de dados após conversão:")
print(df[['Altura', 'Altura_numerica', 'Largura', 'Largura_numerica']].info())


# --- 3. Cálculo da Área e Ajuste de Unidade ---
print("\nCalculando a área...")

# Assumindo que as medidas originais estão em MILÍMETROS (mm)
# A área calculada estará em milímetros quadrados (mm²)
df['Area_mm2'] = df['Altura_numerica'] * df['Largura_numerica']

# Convertendo a área de mm² para METROS QUADRADOS (m²)
# Fator de conversão: 1 m² = 1,000,000 mm² (1000mm * 1000mm)
df['Metragem_m2'] = df['Area_mm2'] / 1000000


# --- 4. Verificação do Resultado ---
print("\nCálculo finalizado. Amostra do resultado:")

# Seleciona colunas relevantes para mostrar o resultado
colunas_para_ver = [
    'Componente',
    'Altura',
    'Largura',
    'Metragem_m2' # Nossa coluna final!
]

# Mostra as linhas onde o cálculo resultou em uma área maior que 0
print(df[df['Metragem_m2'] > 0][colunas_para_ver].head(10).to_string())


# --- 5. Opcional: Salvando o arquivo com a nova coluna ---
caminho_saida = 'produtos_com_metragem_calculada.csv'
# Remove as colunas numéricas intermediárias antes de salvar
df.drop(columns=['Altura_numerica', 'Largura_numerica', 'Area_mm2'], inplace=True)
df.to_csv(caminho_saida, index=False, sep=';', encoding='ISO-8859-1')

print(f"\nArquivo final com a metragem calculada foi salvo em: {caminho_saida}")
# Out:
# Iniciando limpeza e conversão das colunas 'Altura' e 'Largura'...
#
# Tipos de dados após conversão:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1142 entries, 0 to 1141
# Data columns (total 4 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Altura            622 non-null    object
#  1   Altura_numerica   1142 non-null   float64
#  2   Largura           622 non-null    object
#  3   Largura_numerica  1142 non-null   float64
# dtypes: float64(2), object(2)
# memory usage: 35.8+ KB
# None
#
# Calculando a área...
#
# Cálculo finalizado. Amostra do resultado:
# Empty DataFrame
# Columns: [Componente, Altura, Largura, Metragem_m2]
# Index: []
#
# Arquivo final com a metragem calculada foi salvo em: produtos_com_metragem_calculada.csv
# /tmp/ipykernel_1935878/2114500802.py:35: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Altura_numerica'].fillna(0, inplace=True)
# /tmp/ipykernel_1935878/2114500802.py:36: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Largura_numerica'].fillna(0, inplace=True)

# %%
import pandas as pd
import dataframe_image as dfi

# --- 1. CARREGAMENTO DO DATAFRAME ---
try:
    df_corrigido = pd.read_csv(
        r'/home/lucala/HUB AI/Nathor/SPRINT III - nathor/notebook/produtos_com_detalhes_componente.csv',
        sep=';'
    )
    print("DataFrame original carregado com sucesso.")

    # --- 2. CONVERSÃO E LIMPEZA DOS TIPOS DE DADOS ---
    print("\nIniciando a conversão dos tipos de dados...")

    # Dicionário para armazenar colunas que precisam de tratamento especial para números
    colunas_numericas_com_virgula = [
        'Espaçamento',
        'Peso (kg)',
        'Altura'
    ]

    for col in colunas_numericas_com_virgula:
        if col in df_corrigido.columns:
            # Substitui vírgula por ponto e converte para numérico (float)
            # O errors='coerce' transforma qualquer valor que não pode ser convertido em NaN (Nulo)
            df_corrigido[col] = pd.to_numeric(df_corrigido[col].astype(str).str.replace(',', '.'), errors='coerce')

    # Dicionário para converter outras colunas para os tipos corretos
    # Usamos 'Int64' (com 'I' maiúsculo) para permitir valores nulos (NaN) em colunas de inteiros
    tipos_de_dados = {
        'CODIGO_PRODUTO': 'Int64',
        'CODIGO_COMPONENTE': 'Int64',
        'CODIGO_COR': 'Int64',
        'Peças p/ gancheira': 'Int64',
        'PINOS': 'Int64',
        'Estoque Gancheiras': 'Int64'
    }

    # Aplica a conversão de tipos
    for coluna, tipo in tipos_de_dados.items():
        if coluna in df_corrigido.columns:
            try:
                df_corrigido[coluna] = df_corrigido[coluna].astype(tipo)
            except (ValueError, TypeError) as e:
                print(f"  - Aviso: Não foi possível converter a coluna '{coluna}' para '{tipo}'. Erro: {e}")


    print("Conversão de tipos concluída.")
    print("\nTipos de dados após a conversão:")
    print(df_corrigido.info())


    # --- 3. SALVAR O DATAFRAME CORRIGIDO COMO IMAGEM ---
    
    # Estilizando a tabela para melhor visualização
    # Usando as 20 primeiras linhas como exemplo para a imagem
    df_para_imagem = df_corrigido.head(20)

    # Formatando as colunas de ponto flutuante para exibir 2 casas decimais e usar vírgula
    estilos = df_para_imagem.style.format({
        'Espaçamento': '{:,.2f}',
        'Peso (kg)': '{:,.3f}', # 3 casas para o peso
        'Altura': '{:,.2f}'
    }).set_properties(**{'text-align': 'left'}).set_table_styles([dict(selector='th', props=[('text-align', 'left')])])

    # Exportando o DataFrame estilizado
    dfi.export(estilos, 'df_imagem_corrigida.png', table_conversion='matplotlib')

    print("\nDataFrame com tipos corrigidos foi salvo com sucesso como 'df_imagem_corrigida.png'")


except FileNotFoundError:
    print("Erro: O arquivo não foi encontrado. Verifique o caminho do seu .csv.")
except Exception as e:
    print(f"Ocorreu um erro inesperado: {e}")
# Out:
# DataFrame original carregado com sucesso.
#
# Iniciando a conversão dos tipos de dados...
# Conversão de tipos concluída.
#
# Tipos de dados após a conversão:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1142 entries, 0 to 1141
# Data columns (total 19 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   CODIGO_PRODUTO          1141 non-null   Int64
#  1   Complemento             1141 non-null   object
#  2   DESCRICAO_PRODUTO       1141 non-null   object
#  3   CODIGO_COMPONENTE       1141 non-null   Int64
#  4   Complemento_Componente  1141 non-null   object
#  5   Componente              652 non-null    object
#  6   LINHA                   718 non-null    object
#  7   DESCRICAO_COMPONENTE    1141 non-null   object
#  8   DESC_COR                686 non-null    object
#  9   CODIGO_COR              658 non-null    Int64
#  10  DESCRICAO_COR           658 non-null    object
#  11  Linha                   652 non-null    object
#  12  Peças p/ gancheira      652 non-null    Int64
#  13  Espaçamento             652 non-null    float64
#  14  PINOS                   631 non-null    float64
#  15  Estoque Gancheiras      622 non-null    Int64
#  16  Altura                  622 non-null    float64
#  17  Largura                 622 non-null    object
#  18  Peso (kg)               622 non-null    float64
# dtypes: Int64(5), float64(4), object(10)
# memory usage: 175.2+ KB
# None
#
# DataFrame com tipos corrigidos foi salvo com sucesso como 'df_imagem_corrigida.png'
